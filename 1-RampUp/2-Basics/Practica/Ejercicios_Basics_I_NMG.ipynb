# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 0
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print ("¿Por qué esta magnífica tecnología científica,\n\t que ahorra trabajo y nos hace la vida más fácil, \n\t\t nos aporta tan poca felicidad?\n\t\t\t La respuesta es esta, simplemente porque aún no hemos aprendido a usarla con tino \n 'Albert Einstein'")
# Out:
# ¿Por qué esta magnífica tecnología científica,
# 	 que ahorra trabajo y nos hace la vida más fácil,
# 		 nos aporta tan poca felicidad?
# 			 La respuesta es esta, simplemente porque aún no hemos aprendido a usarla con tino
#  'Albert Einstein'

# %%
#si separo las líneas por legibilidad me lo convierte en esto: separa los strings con \. preguntar
print ("¿Por qué esta magnífica tecnología científica,\n\t " \
"que ahorra trabajo y nos hace la vida más fácil, \n\t\t " \
"nos aporta tan poca felicidad?\n\t\t\t " \
"La respuesta es esta, simplemente porque aún no hemos aprendido a usarla con tino \n " \
"\"Albert Einstein\"") #otra opcion es usar las comillas simples por fuera dobles por dentro. 
#otra usar la barra de escape delante de las comillas "
# Out:
# ¿Por qué esta magnífica tecnología científica,
# 	 que ahorra trabajo y nos hace la vida más fácil,
# 		 nos aporta tan poca felicidad?
# 			 La respuesta es esta, simplemente porque aún no hemos aprendido a usarla con tino
#  "Albert Einstein"

# %% [markdown]
# ## Ejercicio 1
# 1. Escribe el nombre de la calle de tu domicilio en una variable
# 2. Escribe el numero de la calle en otra
# 3. Ciudad en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Imprime las 4 variables concatenadas por pantalla
# 6. Crea una quinta variable que concatene todas ellas
# 7. Imprímela por pantalla

# %%
calle = "Maria Diaz de Haro"
numero = 40
ciudad = "Bilbao"
codigo_postal = 48010
print (f"{calle} {numero} {ciudad} {codigo_postal}")
direccion_completa = calle + str(numero) + ciudad + str(codigo_postal)
print (direccion_completa)
# Out:
# Maria Diaz de Haro 40 Bilbao 48010
# Maria Diaz de Haro40Bilbao48010

# %% [markdown]
# ## Ejercicio 2
# Repite el ejercicio 1, pero pidiendo estos datos al usuario mediante un input(), imprimiendo a continuación la dirección completa

# %%
calle = input ("Introduce tu calle")
numero = input ("Introduce el número de tu portal")
ciudad = input ("Introduce tu ciudad")
codigo_postal = input ("Introduce tu codigo postal")
print (f"La direccion completa es: {calle} {numero} {ciudad} {codigo_postal}")
# Out:
# La direccion completa es: Calle Mayor 56 Bilbao 34098

# %% [markdown]
# ## Ejercicio 3
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. import = 40
# 6. 81mi_variable = "Agua"
# 7. mi_variable10 = 6

# %% [markdown]
# 1. Correcta
# 2. Incorrecta. Faltan las comillas de cierre
# 3. Incorrecta. No se puede usar True como nombre de variable. Es palabra reservada
# 4. Correcta NOO! Tenía espacio!
# 5. Incorrecta. No se puede usar import como nombre de variable. Es palabra reservada
# 6. Incorrecta. El nombre de una variable no puede empezar por un número
# 7. Correcta

# %%
mi_variable = "Economía"

# %%
otra_var = "Ejercicio
# Out:
#   Cell In[7], line 1
#     otra_var = "Ejercicio
#                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
True = "Ejercicio"
# Out:
#   Cell In[8], line 1
#     True = "Ejercicio"
#     ^
# SyntaxError: cannot assign to True

# %%
mi_var1able = "Alpha"

# %%
import = 40
# Out:
#   Cell In[10], line 1
#     import = 40
#            ^
# SyntaxError: invalid syntax

# %%
81mi_variable = "Agua"
# Out:
#   Cell In[11], line 1
#     81mi_variable = "Agua"
#      ^
# SyntaxError: invalid decimal literal

# %%
mi_variable10 = 6

# %% [markdown]
# ## Ejercicio 4
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = C × (9 / 5) + 32

# %%
celsius = float (input ("Introduce la temperatura en grados Celsius que quieras convertir"))
#ojo! si mete la temperatura con "," dará error
fahrenheit = round (celsius * (9/5) + 32, 1) 
print (f"{celsius} ºC = {fahrenheit} ºF")
# Out:
# 4.2 ºC = 39.6 ºF

# %% [markdown]
# ## Ejercicio 5
# Comenta  el Ejercicio 4. Pon un comentario multilinea y haz comentarios de cada linea de código

# %%
'''
Este es un comentario multilínea.
Vamos a comentar el ejercicio 4
'''
#Pide la temperatura en celsius y la convierte a float para poder operar con ella
celsius = float (input ("Introduce la temperatura en grados Celsius que quieras convertir"))
#Aplica la fórmula de conversion de celsius a farhenheit limitando a un decimal
fahrenheit = round (celsius * (9/5) + 32, 1)
#Saca por pantalla la equivalencia de grados celsius a farhenheit
print (f"{celsius} ºC = {fahrenheit} ºF")
# Out:
# 45.0 ºC = 113.0 ºF
