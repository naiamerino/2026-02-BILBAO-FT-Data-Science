# %%
import random

def colocar_barcos(tablero):

    barcos = [4,3,3,2,2,2,1,1,1,1]   # tamaños de los barcos

    size = 10

    for barco in barcos:

        colocado = False

        while not colocado:

            fila = random.randint(0,9)
            col = random.randint(0,9)
            orientacion = random.choice(["H","V"])

            posiciones = []

            for i in range(barco):

                if orientacion == "H":
                    f = fila
                    c = col + i
                else:
                    f = fila + i
                    c = col

                if f >= size or c >= size or tablero[f][c] == "B":
                    break

                posiciones.append((f,c))

            if len(posiciones) == barco:
                for f,c in posiciones:
                    tablero[f][c] = "B"
                colocado = True

#Otra
import random

def colocar_barcos(tablero):

    barcos = [4,3,3,2,2,2,1,1,1,1]
    size = 10

    for barco in barcos:

        colocado = False

        while not colocado:

            fila = random.randint(0,9)
            col = random.randint(0,9)
            orientacion = random.choice(["H","V"])

            posiciones = []

            # calcular posiciones del barco
            for i in range(barco):

                if orientacion == "H":
                    posiciones.append((fila, col + i))
                else:
                    posiciones.append((fila + i, col))

            # comprobar si todas son válidas
            valido = True

            for f,c in posiciones:

                if f >= size or c >= size or tablero[f][c] == "B":
                    valido = False
                    break

            # colocar barco
            if valido:
                for f,c in posiciones:
                    tablero[f][c] = "B"

                colocado = True
