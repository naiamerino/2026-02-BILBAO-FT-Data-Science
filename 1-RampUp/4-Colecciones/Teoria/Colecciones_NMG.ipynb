# %% [markdown]
# ![imagen](./img/python.jpg)

# %% [markdown]
# # Python Colecciones
#
# Las colecciones son una manera de agrupar varios elementos. En otros notebooks vimos cómo funcionan las listas, que es la colección más usada, pero se trata solo de la punta del iceberg. Con Python tenemos varias manera de almacenar conjuntos de datos, dependiendo del tipo de dato, finalidad, tipo de acceso y rendimiento.
#
# 1. [Listas](#1.-Listas)
# 2. [Tuplas](#2.-Tuplas)
# 3. [Diccionarios](#3.-Diccionarios)
# 4. [Sets](#4.-Sets)
# 5. [Conversiones entre colecciones](#5.-Conversiones-entre-colecciones)
# 6. [Comprensión de listas](#6.-Comprensión-de-listas)
# 7. [Resumen](#7.-Resumen)

# %% [markdown]
# ## 1. Listas
# Ya conocemos bastante las listas. Veamos un repaso de lo que podemos hacer con ellas, así como algunas funcionalidades nuevas

# %%
# Listas de números, strings, booleanos, con elementos repetidos, listas anidadas...
nums = [6, 2, 8, 3, 4, 5, 5]
months = ["Enero", "Febrero", "Marzo"]
mix = [5, 7, "Abril", True, None, ["Blanco", "Negro"]]

# Longitud de la lista
print(len(nums))

# Indexación
print(months[1])
print(months[len(months)-1])

# %% [markdown]
# ### Acceso
# Entre corchetes introducimos el indice del elemento al que queremos acceder

# %%
print(months[0])
print(months[-1]) #último es -1, el anteúltimo es -2, etc...

# %% [markdown]
# Si planteamos el problema al revés. Tenemos los valores de la lista y lo que queremos es obtener el índice de esos valores dentro de la lista

# %%
months.index("Marzo")

# %% [markdown]
# **Slicing**: usamos slicing para acceder a varios elementos seguidos de la lista

# %%
degrees = [22, 34, 15, 26, 18, 22]

print(degrees[2:4]) #dame todos los elementos entre la dos y la cuatro. No coge la última
print(degrees[1:5]) #me da de la 1 a la 4
print(degrees[1:]) # Hasta el final
print(degrees[-2:]) # Desde el penúltimo al último
print(degrees[2])
print(degrees[2:3])
print(type(degrees[2:3])) # El slicing devuelve una lista
# Out:
# [15, 26]
# [34, 15, 26, 18]
# [34, 15, 26, 18, 22]
# [18, 22]
# 15
# [15]
# <class 'list'>

# %%
degrees = [22, 34, 15, 26, 18, 20]
print(degrees)
print(degrees[0:5:2]) #Puede usarse también como start, stop y step. Indicar de cuanto en cuanto
# Out:
# [22, 34, 15, 26, 18, 20]
# [22, 15, 18]

# %%
degrees[-1:-5:-3]
# Out:
# [20, 15]

# %%
segunda_lista = degrees[2:4]
segunda_lista
# Out:
# [15, 26]

# %% [markdown]
# ### Modificar elementos
# Las listas son mutables, por lo que podremos modificarlas

# %%
print(months)

months[2] = "Abril"
print(months)

# %% [markdown]
# ### Añadir elementos
# Se añade al final de la lista si usamos `append`, o si queremos en un lugar concreto, mediante `insert`

# %%
motos = ['honda', 'yamaha', 'suzuki']
print(motos)

motos.append('ducati')
print(motos)

motos.insert(2, 'kawasaki')
print(motos)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'kawasaki', 'suzuki', 'ducati']

# %%
motos = []

motos.append('ducati')
print(motos)
# Out:
# ['ducati']

# %% [markdown]
# ### Eliminar elementos
# Para eliminar elementos se usar `remove`. Si no existe, da error, así que cuidado con esta sentencia.
#
# En ocasiones resulta útil quedarnos con el elemento eliminado. Para ello usamos `pop()`, que elimina el elemento que le indiquemos, y además devuelve ese elemento por lo que podremos guardarlo en una variable para usarlo después. Si no le indicamos nada quita el último

# %%
cars = ['VW', 'Seat', 'BMW', 'VW']
print(cars)

print(cars.remove('VW'))
print(cars)
# print(cars.remove('VW'))
# print(cars)
# Out:
# ['VW', 'Seat', 'BMW', 'VW']
# None
# ['Seat', 'BMW', 'VW']

# %%
cars = ['VW', 'Seat', 'BMW', 'VW']
print(cars)

cars.remove('VW') # remove quita solo la primera aparición
print(cars)
# print(cars.remove('VW'))
# print(cars)
# Out:
# ['VW', 'Seat', 'BMW', 'VW']
# ['Seat', 'BMW', 'VW']

# %%
cars.append("Lexus")
print(cars)
# Out:
# ['Seat', 'BMW', 'VW', 'Lexus']

# %%
cars_removed = []
cars_removed.append(cars.pop(1))
print(cars_removed)
print(cars)
# Out:
# ['BMW']
# ['Seat', 'VW', 'Lexus']

# %%
print(cars.pop(1))
print(cars)
# Out:
# VW
# ['Seat', 'Lexus']

# %%
help(cars.pop)
# Out:
# Help on built-in function pop:
#
# pop(index=-1, /) method of builtins.list instance
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORES remove</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# ***remove*** da error si el elemento no existe. Por eso es habitual antes de usarlo el chequear si existe el elemento en la lista o no

# %%
cars = ['VW', 'Seat', 'BMW', 'VW']
cars.remove("Audi")

# %%
if "Toyota" in cars:
    print("Sí")
else:
    print("No")

# %% [markdown]
# ### Métodos: ordenar, tamaño, invertir orden, ocurrencia
# En este apartado veremos los métodos más útiles, pero podrás consultar el resto en [este enlace](https://www.w3schools.com/python/python_ref_list.asp)

# %%
degrees = [22, 34, 15, 26, 18, 22]
print(degrees)
print(sorted(degrees))
print(degrees)

# %% [markdown]
# Para ordenar:
# - ***sorted*** devuelve una lista ordenada pero no modifica la original
# - ***sort*** ordena la lista original

# %%
degrees = [22, 34, 15, 26, 18, 22]
print(degrees)

# Ordenar
print(sorted(degrees))
print(degrees)
# print(degrees.sort())
# print(degrees)

print ("reverse")
print(degrees.reverse()) # da la vuelta a la lista (primer elemento al último)
print(degrees)

degrees.count(22)
# Out:
# [22, 34, 15, 26, 18, 22]
# [15, 18, 22, 22, 26, 34]
# [22, 34, 15, 26, 18, 22]
# reverse
# None
# [22, 18, 26, 15, 34, 22]
# 2

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORES indice</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# Mucho cuidado cuando accedemos a los elementos de la lista. Es un error muy habitual acceder a un índice que no existe en la lista.
#
# Si estamos accediendo al último elemento, en vez de poner el numero de su indice, poner mejor `-1`, y asi evitamos errores

# %% [markdown]
# Si tenemos este tipo de errores y no sabemos resolverlos, lo mejor es imprimir la longitud de la lista, y todos los elementos.

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio de listas</h3>
#
# Piensa en al menos 3 personas que invitarías a cenar
# <ol>
#     <li>Utiliza la lista de invitados para imprimir cada uno por pantalla y su índice, mediante un bucle</li>
#     <li>Ordena alfabéticamente tu lista de invitados</li>
#     <li>¿Quién es el primer invitado de la lista?</li>
#     <li>Te llama uno de ellos a última hora, que no va a poder asistir. Elimínalo de la lista</li>
#     <li>Por suerte te ha llamado un amigo que no iba a asistir y al final sí puede. Añádelo a mitad de la lista</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
invitados = ["Ana", "Pedro", "Paco"]
for i, persona in enumerate (invitados):
    print (i, "-", persona)

#Otra opcion para recorrer la lista con el índice
for persona in invitados:
    print (invitados.index(persona), persona)

invitados.sort()
print (invitados)

print (f"El primer invitado de la lista es {invitados[0]}")

no_viene = invitados.pop(1)
print (f"{no_viene} no viene a la cena")

invitados.insert (1, "Lucía")
print ("La lista de invitados final es:")
for i, persona in enumerate (invitados):
    print (i, "-", persona)
# Out:
# 0 - Ana
# 1 - Pedro
# 2 - Paco
# 0 Ana
# 1 Pedro
# 2 Paco
# ['Ana', 'Paco', 'Pedro']
# El primer invitado de la lista es Ana
# Paco no viene a la cena
# La lista de invitados final es:
# 0 - Ana
# 1 - Lucía
# 2 - Pedro

# %% [markdown]
# ## 2. Tuplas
# Muy similares a las listas. Si en Notebooks anteriores definíamos a las listas como ordenadas y mutables, las tuplas son ordenadas e inmutables.
#
# * **Inmutables**: una vez creada la tupla con sus elementos iniciales, no se puede modificar
# * **Ordenadas**: podemos acceder a sus elementos a través del índice y reordenar la tupla según queramos
#
# Las tuplas se suelen usar para pequeñas colecciones de datos que no van a cambiar a lo largo del programa, como es el caso de las constantes.
#
# Si las listas se construían mediante corchetes `[]`, las tuplas lo hacen con los paréntesis `()`

# %%
tupla_vacia = () # crear una tupla vacía
print (type(tupla_vacia), tupla_vacia)
primera_tupla = (3, "text")
print(primera_tupla)
print(type(primera_tupla))
# Out:
# <class 'tuple'> ()
# (3, 'text')
# <class 'tuple'>

# %% [markdown]
# Los paréntesis ya se usan para reordenar operaciones `5 * (3 + 4)`, por lo que hay que añadir una coma cuando definamos una tupla con un único elemento, si no Python lo interpretará como un número.

# %%
otra_tupla = (1)
print(otra_tupla)
print(type(otra_tupla))
# Out:
# 1
# <class 'int'>

# %%
otra_tupla = (1,)
print(otra_tupla)
print(type(otra_tupla))
# Out:
# (1,)
# <class 'tuple'>

# %%
tupla_anid = (1, 2, 3, ("A", "B", "C"))
print(tupla_anid)

print(tupla_anid[0])

for i in tupla_anid:
    print(i)
    
print(tupla_anid[0:2])

print(len(tupla_anid))
# Out:
# (1, 2, 3, ('A', 'B', 'C'))
# 1
# 1
# 2
# 3
# ('A', 'B', 'C')
# (1, 2)
# 4

# %%
tupla_anid = (1, 2, 3, ("A", "B", "C"))

tupla_anid[3][0]

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORES tuplas</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# Cuidado que las tuplas son inmutables, y una vez creadas no las podrás modificar después

# %%
tupla_error = (1,2,3)
tupla_error[0] = 10

# %%
# Si queremos añadir elementos, podemos meterlos en otra tupla y sumarlas para que se concatenen
tupla1 = (1,2,3)
tupla2 = (4,5,6)
tupla3 = tupla1 + tupla2

print(tupla3)

# %% [markdown]
# Si quisiera cambiar los elementos de la tupla puedo sobre escribirla.
# También puedo convertirla a lista, cambiar y volver a convertir a tupla.
# En los dos casos realmente lo que estoy haciendo es crear una nueva con el mismo nombre que machaca la anterior

# %%
print(sorted(tupla3))

# %% [markdown]
# ### Listas y tuplas
# Podemos combinar listas y tuplas que no tendremos ningún problema, siempre y cuando respetemos las propiedades de cada tipo de dato.

# %%
mi_tupla = ("Naranjas", "Limones")
frutas = ["Manzanas", mi_tupla, "Fresas"]
print(frutas)
print(frutas[0])
print(frutas[-1])
print(frutas[1][0])
# Out:
# ['Manzanas', ('Naranjas', 'Limones'), 'Fresas']
# Manzanas
# Fresas
# Naranjas

# %%
list(mi_tupla)
# Out:
# ['Naranjas', 'Limones']

# %%
list(frutas[1])
# Out:
# ['Naranjas', 'Limones']

# %%
new_var = frutas[1]
new_var = list(new_var)
print(type(new_var))
# Out:
# <class 'list'>

# %%
print(type(frutas))
print(frutas)
print(type(frutas[1]))
print((frutas[1]))
# Out:
# <class 'list'>
# ['Manzanas', ('Naranjas', 'Limones'), 'Fresas']
# <class 'tuple'>
# ('Naranjas', 'Limones')

# %%
frutas.append("Melocoton")
print(frutas)
frutas[1].append("Otro melocoton")

# %%
mi_tupla_tolist = list(mi_tupla)
print(mi_tupla_tolist)

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio de tuplas</h3>
#
#
# <ol>
#     <li>Crea una tupla con un único valor. Comprueba su tipo</li>
#     <li>Crea otra tupla con 3 elementos</li>
#     <li>Añadele (como puedas) a la primera tupla, los tres elementos de la segunda</li>
#     <li>Obtén una cuarta tupla a partir de los dos primeros valores de la tupla creada del apartado anterior</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
tupla = (5,)
print (type (tupla))
tupla3 = (4,"palabra",[2,4,5])
tupla = tupla + tupla3
print (tupla)
tupla4 = (tupla[0],tupla[1])
print (tupla4)
#también puede hacerse con slicing:
tupla5 = (tupla [0:2])
tupla5 = (tupla [:2]) #equivalente a lo de arriba
print (tupla5)
# Out:
# <class 'tuple'>
# (5, 4, 'palabra', [2, 4, 5])
# (5, 4)

# %% [markdown]
# ## 3. Diccionarios
# En este tipo de colecciones no solo podemos agrupar datos, sino que tenemos la posibilidad de establecer una relación entre los mismos, con la forma **clave: valor**.
#
# La sintaxis  es mediante llaves `{}`
#
# > nombre_diccionario = {clave1: valor1, clave2: valor2, clave3: valor3}
#
# Si veíamos que las listas son elementos mutables y y ordenadas, y las tuplas inmutables y ordenadas, los diccionarios son:
#
# * **Mutables**: podemos modificar sus elementos
# * **Desordenado**: la potencia de acceso de los diccionarios es su formato clave-valor, no su orden. Aun así, el dicionario conserva el orden de los elemento según los vamos insertando.
#
# Vamos a declarar un diccionario en el que definiremos elementos de un coche

# %%
lista_coche = ["Gris", "VW", 1500, True]
print(lista_coche[0])

# %%
coche = {"color": "Gris",
        "marca": "VW",
        "peso": 1500,
        "Cambio automatico": True}
coche
# Out:
# {'color': 'Gris', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': True}

# %%
print(type(coche))
# Out:
# <class 'dict'>

# %%
coche["color"]
# Out:
# 'Gris'

# %% [markdown]
# ***metodo keys*** Nos devuelve todas las claves de un diccionario

# %%
list(coche.keys())
# Out:
# ['color', 'marca', 'peso', 'Cambio automatico']

# %% [markdown]
# ***metodo values*** Nos devuelve todos los valores de un diccionario

# %%
list(coche.values())
# Out:
# ['Gris', 'VW', 1500, True]

# %% [markdown]
# ***metodo items*** Nos devuelve todos los pares clave-valor de un diccionario

# %%
list(coche.items())
# Out:
# [('color', 'Gris'),
#  ('marca', 'VW'),
#  ('peso', 1500),
#  ('Cambio automatico', True)]

# %%
for clave in coche.keys():
    print("Clave:", clave, "Valor:",coche[clave])
# Out:
# Clave: color Valor: Gris
# Clave: marca Valor: VW
# Clave: peso Valor: 1500
# Clave: Cambio automatico Valor: True

# %% [markdown]
# Esto sería la forma de acceder a un diccionario que sea equivalente a un enumerate en una lista:

# %%
for clave,valor in coche.items():
    print("Clave:", clave, "Valor:",valor)

# %%
coche = {"color": "Gris",
        "marca": "VW",
        "peso": 1500,
        "Cambio automatico": True,
        (1,5): {"Hola": [1,3]}}

# %%
list(coche.keys())

# %%
coche[(1,5)]["Hola"][0] #Dame lo que haya almacenado en la clave (1,5) -> es un diccionario. Dentro de él puedo acceder a sus elementos por clave
# Out:
# 1

# %%
#La clave del diccionario anidado es Hola. Si accedo por Hola me devuelve la lista y si accedo con hola más posición
#me devuelve el elemento de la lista
print (coche [(1,5)]["Hola"])
print (coche[(1,5)]['Hola'][1])
# Out:
# [1, 3]
# 3

# %% [markdown]
# Se puede almacenar todo tipo de datos: numero, cadena, booleano, listas, tuplas, diccionarios...
#
# Cuando declaremos el diccionario, lo podemos hacer en una sola linea `coche = {"color"="Gris", "marca"...}`, aunque se recomienda por sencillez a la hora de leer el código, realizar esta acción en varias líneas. Si escribimos el primer elemento y presionamos enter, Jupyter introduce automáticamente la tabulación.

# %% [markdown]
# ### Acceso, modificación, añadir, eliminar

# %%
coche
# Out:
# {'color': 'Gris',
#  'marca': 'VW',
#  'peso': 1500,
#  'Cambio automatico': True,
#  (1, 5): {'Hola': [1, 3]}}

# %% [markdown]
# Son mutables. Puedo modificarlo

# %%
coche['color'] = coche['color'] + " Blanco"
print(coche)
# Out:
# {'color': 'Gris Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': True, (1, 5): {'Hola': [1, 3]}}

# %%
# Acceso
print(coche['Cambio automatico'])

# Modificar claves que existan
coche['color'] = "Blanco"
print(coche)

# Añadir claves
coche['puertas'] = 4
print(coche)

# Eliminar
# del coche['puertas']
print(coche.pop('puertas')) #elimina y devuelve la clave-valor
print(coche)
# Out:
# True
# {'color': 'Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': True, (1, 5): {'Hola': [1, 3]}}
# {'color': 'Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': True, (1, 5): {'Hola': [1, 3]}, 'puertas': 4}
# 4
# {'color': 'Blanco', 'marca': 'VW', 'peso': 1500, 'Cambio automatico': True, (1, 5): {'Hola': [1, 3]}}

# %%
print(list(coche.keys()))
print(list(coche.values()))

# %% [markdown]
# Para más detalle de los métodos de los diccionario puedes [consultar la documentación](https://www.w3schools.com/python/python_ref_dictionary.asp)

# %%
# Podemos empezar tambien mediante un diccionario vacío
tienda = {}
tienda['Direccion'] = ["Avenida 1", "Avenida 2"]
tienda['Tamaño'] = [110, 90]
print(tienda)
# Out:
# {'Direccion': ['Avenida 1', 'Avenida 2'], 'Tamaño': [110, 90]}

# %%
lista_total = ["Avenida 1", "Avenida 2"] + [110, 90]
print(lista_total)
# Out:
# ['Avenida 1', 'Avenida 2', 110, 90]

# %% [markdown]
# Crear un diccionario a partir de una lista

# %%
my_dict = {}

for i, elem in enumerate(lista_total):
    my_dict[i] = elem

print(my_dict)
# Out:
# {0: 'Avenida 1', 1: 'Avenida 2', 2: 110, 3: 90}

# %% [markdown]
# Si a un diccionario le indicas que almacene algo en una clave:
# + si la clave no existe, la crea
# + si la clave existe, la sobreescribe

# %%
my_dict = {}

# Se queda con la segunda iteración porque hemos sobreescrito las claves
for i, elem in enumerate(lista_total):
    if i < 2:
        my_dict['Dirección'] = elem
    else:
        my_dict['Tamaño'] = elem

print(my_dict)
# Out:
# {'Dirección': 'Avenida 2', 'Tamaño': 90}

# %%
print(my_dict[3])
print(lista_total[3])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(my_dict[3])
#       2 print(lista_total[3])
#
# KeyError: 3

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORES en diccionarios</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# Si hay una clave que no existe en el diccionario, saltará un error.
# **al acceder**. Si intentamos añadirla y no existe la crea
#
# En este caso, el error es bastante intuitivo: `KeyError`, no encuentra la clave

# %%
coche = {"color": "Gris",
        "marca": "VW"}
coche["peso"]
print("Hola")

# %%
if "peso" in coche:
    print(coche["peso"])
else:
    print("Clave peso no existe")
# Out:
# 1500

# %% [markdown]
# **¿Cómo solventar esto?** Siempre tienes la opción de usar el bloque `try/except`, pero en este caso, los diccionarios tienen una solución más elegante: `get(clave, valor si no existe)`

# %%
print(coche)

# %% [markdown]
# **get**
# Si existe la clave devuelve el valor, pero si no devuelve  lo que le pasemos como segundo parámetro

# %%
a = coche.get("peso", "No hay clave de peso")
print(a)
print("Hola")

# %%
help (coche.get)
# Out:
# Help on built-in function get:
#
# get(key, default=None, /) method of builtins.dict instance
#     Return the value for key if key is in the dictionary, else default.

# %%
a = coche.get("ruedas", False)
if a == False:
    print("No hay ruedas")
# Out:
# No hay ruedas

# %% [markdown]
# ### Iterar
# Que el diccionario no esté ordenado, no quiere decir que no podamos iterar sus elementos, ya que también es un **iterable**, como los son las listas o las tuplas.

# %%
coche = {"color": "Gris",
        "marca": "VW"}

for i in coche:
    print(i, coche[i])

# %%
coche = {"color": "Gris",
        "marca": "VW"}

for i in coche.keys():
    print(i, coche[i])

# %%
for i in coche.values():
    print(i)

# %%
for clave, valor in coche.items():
    print(clave, valor)

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio de diccionarios</h3>
#
#
# <ol>
#     <li>Crea un diccionario con las caracteristicas de un televisor: tamaño(float), smarttv(bool) y marca(str)</li>
#     <li>Añade otra característica del tv</li>
#     <li>Modifica una de ellas</li>
#     <li>Imprime por pantalla sus claves, valores.</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
tele = {"tamaño": 15.7,
        "smarttv": True,
         "marca": "Samsung" }
print (tele)

tele ["precio"] = 1500
print (tele)

tele ["smarttv"] = False

print (tele)
print (tele.items()) #items devuelve una lista con una tupla por cada par clave-valor!!!

#Utilizando el * desempaqueta el diccionario pero sólo en sus claves
print (*tele)
# Out:
# {'tamaño': 15.7, 'smarttv': True, 'marca': 'Samsung'}
# {'tamaño': 15.7, 'smarttv': True, 'marca': 'Samsung', 'precio': 1500}
# {'tamaño': 15.7, 'smarttv': False, 'marca': 'Samsung', 'precio': 1500}
# dict_items([('tamaño', 15.7), ('smarttv', False), ('marca', 'Samsung'), ('precio', 1500)])
# tamaño smarttv marca precio

# %% [markdown]
# ## 4. Sets
# Otra colección *built-in* de Python, compuesta por un conjunto de *claves*. Muy parecidos a los diccionarios. Tienen las siguientes características:
# * **Mutables**: podemos modificarlos una vez se hayan creado
# * **No ordenados**
# * **Elementos únicos**: se compone de un conjunto de claves únicas
#
# **¿Cuándo usar sets?** Cuando estemos buscando unicidad en nuestros datos y no nos importe el orden.
#
# Te dejo por aquí [la documentación](https://docs.python.org/2/library/sets.html) para realizar consultas sobre los sets
#
# Su sintaxis es:
# >```Python
# > mi_set = {elemento1, elemento2, elemento3}
# >```
#
# Tiene una sintaxis muy parecida a la de los diccionarios, pero en este caso no se utilizan los `:`.

# %%
colores = {"rojo", "azul", "blanco"}
print(colores)

colores2 = {"rojo", "azul", "blanco", "rojo"} #no guarda los valores repetidos
print(colores2)

len(colores2)
# Out:
# {'rojo', 'blanco', 'azul'}
# {'rojo', 'blanco', 'azul'}
# 3

# %% [markdown]
# Los elementos del set son unicos, por lo que si en la declaración, o posteriormente añadiendo elementos hubiese algún duplicado, el set lo ignoraría. Es más, cuando aplicas el `len`, muestra la cantidad de valores únicos que tiene.

# %%
dias = {'dia', 4}
print(dias)

dias = set() #equivalente a set (dias)

# Para añadir elementos los sets usan add y no append
dias.add("Lunes")
dias.add("Martes")
print(dias)

dias.remove("Martes")
print(dias)

print("Lunes" in dias)
print("Viernes" not in dias)

for i in dias:
    print(i)
# Out:
# {4, 'dia'}
# {'Martes', 'Lunes', 4, 'dia'}
# {'Lunes', 4, 'dia'}
# True
# True
# Lunes
# 4
# dia

# %% [markdown]
# Para comprobar si dos sets tienen los mismos elementos

# %%
lista = [1,2,3,5]
lista[1]

# %%
set1 = {1,3,5,1,7,6,1,3}
set2 = {5,1,3,7,6}

set1 == set2

#Es true porque tienen los mismos elementos únicos
# Out:
# True

# %% [markdown]
# ***pop*** quita un elemento arbitrario, no hay certeza de qué se quita

# %%
set2.pop()
print(set2)
# Out:
# {3, 5, 6, 7}

# %%
set_strings = {'s', 'a', 'e'}
set_strings.pop()
print (set_strings)
print (help(set_strings.pop))
# Out:
# {'e', 'a'}
# Help on built-in function pop:
#
# pop(...) method of builtins.set instance
#     Remove and return an arbitrary set element.
#     Raises KeyError if the set is empty.
#
# None

# %%
print(set1)
print(set2)

# %%
if 1 in set1:
    print("hay un 1")

# %%
set1 = {1,3,5,1,7,6,1,3}
set2 = {5,1,3,10}

print(set1)
print(set2)
print('-'*10)

print(set1 & set2) # and Devuelve los elementos que están en común en los dos sets
print(set1 | set2) # or  Devuelve los elementos que estén en cualquiera de los dos (o sea todos)
print(set1 - set2) # Devuelve solo los elementos que están en el set1
print(set2 - set1)
# Out:
# {1, 3, 5, 6, 7}
# {1, 10, 3, 5}
# ----------
# {1, 3, 5}
# {1, 3, 5, 6, 7, 10}
# {6, 7}
# {10}

# %% [markdown]
# ## 5. Conversiones entre colecciones
#
# ### De lista

# %%
list_1 = [1,2,3,3,3,3,3,3,3]
print(list_1)

# A tupla
tuple_1 = tuple(list_1)
print(tuple_1)

# A set --> solo pasa los valores únicos
print(set(list_1))
# Out:
# [1, 2, 3, 3, 3, 3, 3, 3, 3]
# (1, 2, 3, 3, 3, 3, 3, 3, 3)
# {1, 2, 3}

# %% [markdown]
# ### De Tupla

# %%
tupla_1 = (1,2,3)
print(tupla_1)

# A lista
print(list(tupla_1))

# A set
print(set(tupla_1))

# A diccionario
# CUIDADO aquí, o tenemos una lista que tenga claves de pares valor o no podrá hacerlo
lista_tuplas = [("Ciudad", "Madrid"), ("Tiempo", "nublado")]
print(dict(lista_tuplas))
# Out:
# (1, 2, 3)
# [1, 2, 3]
# {1, 2, 3}
# {'Ciudad': 'Madrid', 'Tiempo': 'nublado'}

# %%
# Error
lista_enteros = [4, 5, 3, 6, 3, 1] 
print (dict(lista_enteros))

# %%
#Esto sí lo convierte
lista_elementos = [["Hola", 34], ["Pez", "Trucha"]]
print (dict(lista_elementos))
# Out:
# {'Hola': 34, 'Pez': 'Trucha'}

# %%
diccionario = dict(lista_tuplas)
diccionario

# %%
list(diccionario.items())

# %%
tupla = (1,2,2,3,3,4)
my_dict = {}
for i, elem in enumerate(tupla):
    my_dict[i] = elem

print(my_dict)

# %% [markdown]
# ### De diccionario

# %%
tupla_dict = [("Ciudad", "Madrid"), ("Tiempo", "nublado")]
dict_1 = dict(tupla_dict)
print(dict_1)

# A lista --- se queda con las claves
print(list(dict_1))

# A tupla --- se queda con las claves
print(tuple(dict_1))

# A set --- se queda con las claves
print(set(dict_1))

#Si quiero las claves y los valores tendré que usar items

# A lista
print(list(dict_1.items()))

# A tupla
print(tuple(dict_1.items()))

# A set
print(set(dict_1.items()))
# Out:
# {'Ciudad': 'Madrid', 'Tiempo': 'nublado'}
# ['Ciudad', 'Tiempo']
# ('Ciudad', 'Tiempo')
# {'Ciudad', 'Tiempo'}
# [('Ciudad', 'Madrid'), ('Tiempo', 'nublado')]
# (('Ciudad', 'Madrid'), ('Tiempo', 'nublado'))
# {('Ciudad', 'Madrid'), ('Tiempo', 'nublado')}

# %%
#También podemos hacerlo mediante un bucle

mi_list = []

for clave, valor in dict_1.items():
    mi_list.append(clave)
    mi_list.append(valor)

mi_list

# %%
mi_list = []

for i in dict_1:
    mi_list.append(i)
    mi_list.append(dict_1[i])

mi_list

# %%
#Al iterar sobre un diccionario por defecto lo que obtenemos son sólo las claves
for i in dict_1:
    print(i)
for i in dict_1.keys():
    print(i)
for i in list(dict_1):
    print(i)
# Out:
# Ciudad
# Tiempo
# Ciudad
# Tiempo
# Ciudad
# Tiempo

# %% [markdown]
# Se queda únicamente con las claves, y perdemos los valores. Para no perder la informacion:

# %%
print(dict_1.keys())
print(dict_1.values())
print(dict_1.items())

# %% [markdown]
# ### De Set

# %%
set_1 = {1,2,3}
print(set_1)

print(list(set_1))
print(tuple(set_1))

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORES en conversiones</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# El diccionario suele dar problemas cuando intentamos realizar conversiones entre colecciones, ya que es la estructura más compleja.
#
# *Para convertir a diccionario dará error siempre que no haya pares clave valor.
# Para hacer la conversión inversa puede no dar valor pero corremos el riesgo de perder datos porque sólo convertirá las claves*

# %%
mi_tupla = (1,2,3)
dict(mi_tupla)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 mi_tupla = (1,2,3)
# ----> 2 dict(mi_tupla)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %% [markdown]
# ## 6. Comprensión de listas
#
# Las listas pueden crearse también por comprensión (en inglés, *comprehension*). Esto tiene mucha relación con la definición de conjuntos por comprensión de las matemáticas. Sea por ejemplo, en matemáticas esta expresión:
# $$ S = \{x^2 |\ x \in [3, 7), x \  impar\}$$
# Esta expresión define un conjunto $ S = \{9, 25\}$, puesto que el intervalo es abierto por la derecha, con lo que solo comprende los números 3, 4, 5 y 6, pero la condición dice que solo tengamos en cuenta los impares, es decir, 3 y 5, y la expresión del principio dice que tomemos los cuadrados. Recordando que para saber si un número es par o impar usamos en Python el operador módulo (`%`), esto se puede escribir (definiendo una lista `s` en lugar de un conjunto) como:

# %%
list_comp = []
for x in range(3,7): #range ya lo hace así: incluye el primero y excluye el último
    if x % 2 == 1:
        list_comp.append(x**2)

print(list_comp)
# Out:
# [9, 25]

# %%
tablero = []
for i in range(10):
    linea = []
    for j in range(10):
        linea.append(" ")
    tablero.append(linea)
tablero
# Out:
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]

# %%
# Hace lo mismo que lo anterior
tablero_2 = [[" " for i in range(10)] for j in range(10)]
tablero_2
# Out:
# [[' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]

# %%
# Hace lo mismo que el primer ejemplo
list_comp = [x**2 for x in range(3, 7) if x % 2 == 1]
print(list_comp)
# Out:
# [9, 25]

# %%
#Añadimos un else, para los pares que me guarde el valor 
list_comp = [x**2 if x % 2 == 1 else x for x in range(3, 7)]
print(list_comp)
# Out:
# [9, 4, 25, 6]

# %%
list_comp = [x + "-encontrada" for x in "Hola mundo" if x == "o"]
list_comp
# Out:
# ['o-encontrada', 'o-encontrada']

# %%
#Si queremos añadir un else a la sentencia anterior hay que cambiar el orden
list_comp = [x + "-encontrada" if x == "o" else (x + "-not found")for x in "Hola mundo"]
list_comp
# Out:
# ['H-not found',
#  'o-encontrada',
#  'l-not found',
#  'a-not found',
#  ' -not found',
#  'm-not found',
#  'u-not found',
#  'n-not found',
#  'd-not found',
#  'o-encontrada']

# %%
#Este es el código de arriba desempaquetado
list_comp_text = []
for letra in "Hola mundo":
    if letra == "o":
        list_comp_text.append(letra + "-encontrada")
list_comp_text

# %% [markdown]
# Si tenemos un trozo de código que define una lista de este tipo:
# ``` python
# nueva_lista = []
# for e in vieja_lista:
#     if filtro(e):
#         nueva_lista.append(transformacion(e))
# ```
# Se puede escribir, usando comprensión, como:
# ```python
# nueva_lista = [transformacion(e) for e in vieja_lista if filtro(e)]
# ```
#
# La definición de listas por comprensión es muy cómoda, compacta y expresiva. No obstante, no debemos abusar de ella; si la expresión que escribimos es muy compleja se puede volver muy difícil de leer. En ese caso sería preferible la definición "clásica" de la lista.
#
# Vamos a ver esto con un ejemplo. Supongamos una lista de `edades`, de la que queremos obtener una nueva lista, `mayores_edad` con las que sean mayores o iguales que 21. Escribiríamos:

# %%
edades = [19, 20, 18, 21, 19, 25, 16]
print(edades)
mayores_edad = [x for x in edades if x >= 18]
print(mayores_edad)

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio list comprehension</h3>
#
# Prueba a definir una lista temperaturas_menores, a partir de la lista temperaturas, con temperaturas menores que 27 grados, guardando los valores con un redondeo de 0 decimales.
#
#          temperaturas = [25.2, 24.9, 25.2, 26.7, 28.6, 29.5, 29.7]
#
#  </td></tr>
# </table>

# %%
temperaturas = [25.2, 24.9, 25.2, 26.7, 28.6, 29.5, 29.7]
temperaturas_menores = [round (x,0) for x in temperaturas if x < 27]
print (temperaturas_menores)

print (type (temperaturas_menores [0]))
#round (x, 0) devuelve un float
#round(x) devuelve un entero
# Out:
# [25.0, 25.0, 25.0, 27.0]
# <class 'float'>

# %% [markdown]
# ## 7. Resumen

# %%
# Listas
print("Listas")
nums = [6, 2, 8, 3, 4, 5, 5]

# Tamaño
print(len(nums))

# Acceso
print(nums[2])
print(nums[-1])

# Acceso por indice
print(nums.index(5))
nums.append('numeros')
print(nums)

# Eliminar
nums.remove("numeros")
print(nums)

# Ordenar
nums.sort()
print(nums)

# Tamaño de la lista
print(len(nums))

# Invertir el orden
nums.reverse()
print(nums)

# Ocurrencia de un valor
print(nums.count(22))
# Out:
# Listas
# 7
# 8
# 5
# 5
# [6, 2, 8, 3, 4, 5, 5, 'numeros']
# [6, 2, 8, 3, 4, 5, 5]
# [2, 3, 4, 5, 5, 6, 8]
# 7
# [8, 6, 5, 5, 4, 3, 2]
# 0

# %%
# Tuplas
primera_tupla = (3, "text")

# Anidacion de tuplas
tupla_anid = (1, 2, 3, ("A", "B", "C"))
print(tupla_anid)

# El acceso es como en las listas
print(tupla_anid[0])

# Tambien son elementos iterables
for i in tupla_anid:
    print(i)
    
# El slicing también funciona igual
print(tupla_anid[0:2])

# Longitud de la tupla
print(len(tupla_anid))

# %%
# Diccionario
coche = {"color": "Gris",
        "marca": "VW",
        "peso": 1500,
        "Cambio automatico": True}

print(coche)

coche = {"color": "Gris",
        "marca": "VW"
        }

for i in coche: # Esta recorriendo las claves
    print(i) # Imprimimos la clave
    print(coche[i]) # Imprimimos el valor
    
# Otra menera de recorrer los elementos
for clave, valor in coche.items():
    print(clave, valor)

# %%
# Sets
colores = {"rojo", "azul", "blanco"}
print(colores)

# Mira lo que ocurre cuando ponemos duplicados
colores2 = {"rojo", "azul", "blanco", "rojo"}
print(colores2)

# El len tambien funciona aqui
len(colores2)

# Crear un set vacio. No se crea con {}, ya que si no, sería un diccionario.
dias = set()
print(dias)

# Añadir elementos
dias.add("Lunes")
dias.add("Martes")
dias.add("Miercoles")
print(dias)

# Eliminar elementos
dias.remove("Miercoles")
print(dias)

# Buscar elementos
print("Lunes" in dias)
print("Viernes" not in dias)

# Tambien es un iterable
for i in dias:
    print(i)
# Out:
# {'rojo', 'blanco', 'azul'}
# {'rojo', 'blanco', 'azul'}
# set()
# {'Martes', 'Lunes', 'Miercoles'}
# {'Martes', 'Lunes'}
# True
# True
# Martes
# Lunes
