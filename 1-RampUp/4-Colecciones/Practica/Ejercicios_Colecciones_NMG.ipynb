# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## Ejercicio 1
# Dada la siguiente lista:
# > ```ejer_1 = [1,2,3,4,5]```
#
# Inviértela para que quede de la siguiente manera
# > ```ejer_1 = [5,4,3,2,1]```

# %%
ejer_1 = [1,2,3,4,5]
ejer_1.reverse()
print (ejer_1)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## Ejercicio 2
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]
for i, elemento in enumerate (ejer_2):
    ejer_2 [i] = elemento**2
print (ejer_2)
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Ejercicio 3
# Crea una lista nueva con todas las combinaciones de las siguientes dos listas:
# > ```ejer_3_1 = ["Hola", "amigo"]```
# >
# > ```ejer_3_2 = ["Que", "tal"]```
#
# Obten el siguiente output:
#
# ```['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']```

# %%
ejer_3_1 = ["Hola", "amigo"]
ejer_3_2 = ["Que", "tal"]

ejer_3 = []
for i in ejer_3_1:
    for j in ejer_3_2:
        ejer_3.append (i + " "+ j)
print (ejer_3)
# Out:
# ['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']

# %% [markdown]
# ## Ejercicio 4
# Dada la siguiente lista, encuentra por el índice el valor 45 y sustitúyelo por el 0
# > ```ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]```

# %%
## funciona si hay uno
ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]

posicion = ejer_4.index (45)
ejer_4 [posicion] = 0

print (ejer_4)
# Out:
# [20, 47, 19, 29, 0, 67, 78, 90]

# %%
## si hay mas
ejer_4 = [20, 45, 19, 29, 45, 67, 78, 90]

for elemento in ejer_4:
    try:
        posicion = ejer_4.index(45)
        ejer_4 [posicion] = 0
    except: #cuidado porque cuando no encuentre el indice da error
        break
print (ejer_4)
# Out:
# [20, 0, 19, 29, 0, 67, 78, 90]

# %%
#otra posibilidad si hay mas
ejer_4 = [20, 45, 19, 29, 45, 67, 78, 90]

for elemento in ejer_4:
    if elemento == 45:
        ejer_4.remove (45)
print (ejer_4)
# Out:
# [20, 19, 29, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 5
# Dada la siguiente lista, elimina todos los valores iguales a 3
# > ```ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]```
#
# TIP: No intentes eliminar elementos sobre la lista que estás iterando. Haz una copia con `ejer_5.copy()`.

# %%
ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]
bis = ejer_5.copy()

# ejer_5.remove (3)
for elemento in bis:
    if elemento == 3:
        ejer_5.remove (elemento)
print (ejer_5)
# Out:
# [20, 47, 19, 29, 45, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 6
# 1. Crea una tupla con 3 elementos
# 2. Crea otra tupla con un elemento y comprueba su tipo
# 3. Crea una tupla con elementos de diferentes tipos
# 4. Imprime por pantalla el primer y último elemento de la tupla del apartado 3. Usa `len` para el último
# 5. Añade un elemento a la tupla del apartado 3.
# 6. Eliminar un elemento de la tupla del apartado 5, que se encuentre más o menos en la mitad.
# 7. Convierte la tupla del apartado 5 en una lista

# %%
#1.
tupla1 = ("cadena", 4, [3, 7])
#2.
tupla2 = (3,)
print (type (tupla2))
#3.
tupla3 = ("string", 4, (2,3), [8, "letra"], 8.98)
#4.
print (tupla3[0], tupla3 [len(tupla3)-1])
#5.
tupla3 = tupla3 + ("nuevo",)
print (tupla3)
#6.
list3 = list (tupla3)
list3.pop (len(list3)//2)
tupla3 = tuple (list3)
print (tupla3)
#7.
list4 = list (tupla3)
print(list4)
# Out:
# <class 'tuple'>
# string 8.98
# ('string', 4, (2, 3), [8, 'letra'], 8.98, 'nuevo')
# ('string', 4, (2, 3), 8.98, 'nuevo')
# ['string', 4, (2, 3), 8.98, 'nuevo']

# %% [markdown]
# ## Ejercicio 7
# Concatena todos los elementos de la tupla en un único string. Para ello utiliza el metodo `.join()` de los Strings
# > ```ejer_7 = ("cien", "cañones", "por", "banda")```
#
# Resultado: `cien cañones por banda`

# %%
ejer_7 = ("cien", "cañones", "por", "banda")
#help (str.join)
string = " ".join (ejer_7)
print (string)
# Out:
# cien cañones por banda

# %% [markdown]
# ## Ejercicio 8
# Obten el tercer elemento de la siguiente tupla, y el tercero empezando por la cola
# > ```ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)```

# %%
ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)
tercero = ejer_8 [2]
antepenultimo = ejer_8 [-3]
print (tercero, antepenultimo)
# Out:
# 3 90

# %% [markdown]
# ## Ejercicio 9
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posición 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_9`?
# 4. Comprueba si el numero 60 está en la tupla
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
#1
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
num = ejer_9.count (3)
print (f"El 3 aparece {num} veces en la tupla")

#2
tupla = ejer_9 [5:10]

#3
print (len (tupla))

#4 Dos opciones
print (60 in tupla)

if (tupla.count (60)):
    print (True)
else:
    print (False)
# Out:
# El 3 aparece 7 veces en la tupla
# 5
# False
# False

# %% [markdown]
# ## Ejercicio 10
# 1. Convierte la tupla del ejercicio 9 en una lista
# 2. Convierte la tupla del ejercicio 9 en un set
# 3. Convierte la tupla del ejercicio 9 en un diccionario. Usa también los índices

# %%
print(list(ejer_9))
print (set (ejer_9))

dict_1 ={}
for i, elemento in enumerate (ejer_9):
    dict_1 [i] = elemento
print (dict_1)
# Out:
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]
# {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29}
# {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}

# %% [markdown]
# ## Ejercicio 11
# Convierte la siguiente lista en un diccionario
# > ```ejer_11 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]```
#
# TIP: Puedes usar dos variables de control en un bucle `for`. Una por cada valor de las tuplas.

# %%
ejer_11 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]

# No puede haber claves repetidas así que se queda con la última

#Lo haría directamente sin necesidad de for, ¿no?
diccionario = dict (ejer_11)
print (diccionario) 

# Usando for

diccionario = {}
for tupla in ejer_11:
    diccionario [tupla[0]] = tupla [1]

print (diccionario)

# Revisar. No FUNCIONA!!
ejer_11 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]
nuevo = {}

for clave, valor in ejer_11:
    if clave in nuevo:
        nuevo[clave].append(valor)
    else:
        # print ("clave", type(clave))
        # print("valor",type (valor))
        # print (nuevo[clave])
        nuevo[clave] = [valor] #si le quito los corchetes no funciona ¿por qué??
print (nuevo)
# for i, j in ejer_11:
#     if i in nuevo:
#         nuevo[i].append(j)
#     else:
#         nuevo [i] = j 


# ejer_11_results = {}
# for clave, valor in ejer_11:
#     print(clave, valor)
#     if clave in ejer_11_results:
#         ejer_11_results[clave].append(valor)
#     else:
#         ejer_11_results[clave] = [valor] #si quito los paréntesis no funciona. no entiendo
# Out:
# {'x': 3, 'y': 2, 'z': 1}
# {'x': 3, 'y': 2, 'z': 1}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 23
#      21 for clave, valor in ejer_11:
#      22     if clave in nuevo:
# ---> 23         nuevo[clave].append(valor)
#      24     else:
#      25         # print ("clave", type(clave))
#      26         # print("valor",type (valor))
#      27         # print (nuevo[clave])
#      28         nuevo[clave] = (valor) #si le quito los corchetes no funciona ¿por qué??
#
# AttributeError: 'int' object has no attribute 'append'

# %% [markdown]
# ## Ejercicio 12
# 1. Crea una lista ordenada ascendente con las claves del diccionario
# 2. Crea otra lista ordenada descendente con los valores
# 3. Añade una nueva clave/valor
# 4. Busca la clave igual a 2 dentro del diccionario
# 5. Itera la clave y el valor del diccionario con un único for
# > ```ejer_12 = {4:78, 2:98, 8:234, 5:29}```

# %%
ejer_12 = {4:78, 2:98, 8:234, 5:29}

#1
claves = list(ejer_12.keys())
claves.sort()
print (claves)

#2
valores = list(ejer_12.values())
valores.sort(reverse=True)
print (valores)

#3
ejer_12 [6] = 78
print (ejer_12)

#4
valor= ejer_12.get(2)
print (valor)

#5
for clave, valor in ejer_12.items():
    print (clave, "=", valor)
# Out:
# [2, 4, 5, 8]
# [234, 98, 78, 29]
# {4: 78, 2: 98, 8: 234, 5: 29, 6: 78}
# 98
# 4 = 78
# 2 = 98
# 8 = 234
# 5 = 29
# 6 = 78

# %% [markdown]
# ## Ejercicio 13
# Junta ambos diccionarios. Para ello, utiliza `update`
# > ```ejer_13_1 = {1: 11, 2: 22}```
# >
# > ```ejer_13_2 = {3: 33, 4: 44}```

# %%
ejer_13_1 = {1: 11, 2: 22}
ejer_13_2 = {3: 33, 4: 44}

ejer_13_1.update (ejer_13_2)
print (ejer_13_1)
# Out:
# {1: 11, 2: 22, 3: 33, 4: 44}

# %% [markdown]
# ## Ejercicio 14
# Suma todos los valores del dicionario
# > ```ejer_14 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_14 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

suma = 0
for valor in ejer_14.values():
    suma = suma + valor
print (suma)

#MAS FACIL!!!
print (sum (ejer_14.values()))
# Out:
# 165
# 165

# %% [markdown]
# ## Ejercicio 15
# Multiplica todos los valores del diccionario
# > ```ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

multi = 1
for valor in ejer_15.values():
    multi = multi * valor
print (multi)

#Otra opcion
import math

print (math.prod (ejer_15.values()))
# Out:
# 19326120
# 19326120

# %% [markdown]
# ## Ejercicio 16
# 1. Crea un set de tres elementos
# 2. Añade un cuarto
# 3. Elimina el último elemento añadido
# 4. Elimina el elemento 10, si está presente. Usa `discard()`

# %%
set1 = {"uno", 6, 9}
set1.add ("nuevo")
print (set1)

set1.remove ("nuevo")
print (set1)

set1.discard (10) #lo elimina solo si existe
print (set1)
# Out:
# {9, 'nuevo', 6, 'uno'}
# {9, 6, 'uno'}
# {9, 6, 'uno'}
