# %%
import numpy as np
import pandas as pd

# %%
# Sintaxis para crearlos


area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
             'Florida': 170312, 'Illinois': 149995}
area = pd.Series(area_dict)

# A partir de dos diccionarios
states = pd.DataFrame({'population': population,
                       'area': area})

#A partir de un diccionario de Series
pd.DataFrame(data=population, columns=['population'])
states = pd.DataFrame({'population': population,
                       'area': area})

#A partir de un Numpy
np.random.seed(10)
print (np.random.rand(3,2))
x = pd.DataFrame(np.random.rand(3, 2),
             columns=['Columna_1', 'Columna_2'],
             index=['a', 'b', 'c'])
# Out:
# [[0.77132064 0.02075195]
#  [0.63364823 0.74880388]
#  [0.49850701 0.22479665]]
