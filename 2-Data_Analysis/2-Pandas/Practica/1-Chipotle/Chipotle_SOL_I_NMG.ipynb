# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) and assign it to a variable called chipo.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep="\t")
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 3. Name of the max valued product

# %%
chipo ["item_name"] [chipo ["item_price"].idxmax()]
# Out:
# 'Steak Salad Bowl'

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
# Había hecho esto pero no lo estaba haciendo bien
#chipo ["item_price"] = chipo ["item_price"].str.replace ("$","").astype(float) 

# Así que he copiado de chatgpt
chipo["item_price"] = (
    chipo["item_price"]
    .str.replace("$", "", regex=False)  # quita el $
    .astype(float)                       # convierte a float
)

#chipo ["item_name"][chipo["item_price"] > 10.00].value_counts() 
#nunique devuelve número de elementos únicos
chipo [chipo["item_price"] > 10.00] ["item_name"].nunique()
# Out:
# 31

# %% [markdown]
# ### Step 4.1: Y cuántos pedidos se han hecho con un producto de más de 10$? Es lo mismo?

# %%
# No es lo mismo. Cada pedido tiene varias líneas
chipo [chipo["item_price"] > 10]["order_id"].nunique()
# Out:
# 863

# %% [markdown]
# ### Step 4.2: Y cuántos pedidos se han hecho de más de 10$? Es lo mismo?

# %%
# Tampoco es lo mismo. Cada producto en cada pedido es una línea. Habría que multiplicar item_price x quantity
# de todos los productos del mismo id y sumarlos

chipo ["total_prize"] = chipo ["quantity"]*chipo["item_price"]
#chipo.groupby?

totales_pedido = chipo.groupby(["order_id"])["total_prize"].sum()
totales_pedido [totales_pedido > 10].nunique()
# Out:
# 446

# %% [markdown]
# ### Step 4.3: Y en cuántos pedidos se ha pagado más de 10$ por un mismo producto? Es lo mismo?

# %%
# En total_prize está el precio total de cada producto en cada pedido

chipo[chipo["total_prize"]>10]["order_id"].nunique()
# Out:
# 889

# %% [markdown]
# ### Step 5. What is the price of each item and name it unit_price. Get only item_name and unit_price

# %%
#chipo ["item_price"].rename ("unit_price") MAL
chipo.rename (columns = {"item_price": "unit_price"}, inplace = True)
items_prices = chipo.loc [:,["item_name","unit_price"]]
items_prices
# Out:
#                                   item_name unit_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
items_prices.sort_values (by="item_name").drop_duplicates (["item_name"])
# Out:
#                                   item_name unit_price
# 3389                      6 Pack Soft Drink    $12.98
# 418                           Barbacoa Bowl     $9.25
# 1202                       Barbacoa Burrito    $11.75
# 1019                  Barbacoa Crispy Tacos     $8.99
# 3546                    Barbacoa Salad Bowl    $11.89
# 3548                    Barbacoa Soft Tacos    $11.75
# 2441                          Bottled Water     $7.50
# 673                                    Bowl     $7.40
# 760                                 Burrito     $7.40
# 1142                            Canned Soda     $1.09
# 964                       Canned Soft Drink     $1.25
# 1359                          Carnitas Bowl     $8.99
# 1097                       Carnitas Burrito    $11.75
# 554                   Carnitas Crispy Tacos     $9.25
# 3750                         Carnitas Salad     $8.99
# 2610                    Carnitas Salad Bowl    $11.89
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered? 2 ways

# %%
#Encontrar el producto más caro y sumar todas sus quantitys
# totales_pedido = chipo.groupby(["order_id"])["total_prize"].sum()
#Esta mal porque no es steak salad bowl
most_expensive = chipo.loc[chipo ["unit_price"].idxmax(), "item_name"]

chipo[chipo["item_name"] == most_expensive]["quantity"].sum()
# Out:
# np.int64(31)

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?
