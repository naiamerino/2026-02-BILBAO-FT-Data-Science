# %%
import pandas as pd

# %%
add_vivienda = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_vivienda\addinfo.csv")

# %%
add_vivienda.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   poblacion  106 non-null    str
#  1   source     106 non-null    str
#  2   valor      106 non-null    str
# dtypes: str(3)
# memory usage: 2.6 KB

# %%
add_vivienda.head(5)
# Out:
#              poblacion    source      valor
# 0       Total Nacional  Empresas  3.337.646
# 1          02 Albacete  Empresas     26.743
# 2  03 Alicante/Alacant  Empresas    138.964
# 3           04 Almería  Empresas     42.931
# 4       01 Araba/Álava  Empresas     19.147

# %%
madrid = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_vivienda\houses_madrid.csv")

# %%
madrid.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5255 entries, 0 to 5254
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ad_description     5184 non-null   str
#  1   ad_last_update     5255 non-null   str
#  2   air_conditioner    5255 non-null   str
#  3   balcony            5255 non-null   str
#  4   bath_num           5255 non-null   str
#  5   built_in_wardrobe  5255 non-null   str
#  6   chimney            5255 non-null   str
#  7   condition          5003 non-null   str
#  8   construct_date     2252 non-null   str
#  9   energetic_certif   3990 non-null   str
#  10  floor              5135 non-null   str
#  11  garage             1829 non-null   str
#  12  garden             5255 non-null   str
#  13  ground_size        7 non-null      str
#  14  heating            2857 non-null   str
#  15  house_id           5255 non-null   str
#  16  house_type         5255 non-null   str
# ...

# %%
madrid.head(5)
# Out:
#                                       ad_description  \
# 0  Particular vende piso de 103 m² en Pinto, prov...
# 1  El suelo de la planta superior es de tarima, l...
# 2                                                NaN
# 3                                                NaN
# 4  Parque Europa. Plaza David Martín junto ambula...
#
#                        ad_last_update air_conditioner balcony bath_num  \
# 0  Anuncio actualizado el 10 de abril               1       0        1
# 1       más de 5 meses sin actualizar               1       0        2
# 2       más de 5 meses sin actualizar               0       0        2
# 3       más de 5 meses sin actualizar               1       0        3
# 4       más de 5 meses sin actualizar               1       0        2
#
#   built_in_wardrobe chimney                 condition construct_date  \
# 0                 0       0  segunda mano/buen estado           1976
# 1                 1       0  segunda mano/buen estado            NaN
# ...

# %%
#Qué son estos
dataset39363 = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_vivienda\39363.csv", sep=";")
dataset39363.head(5)
# Out:
#    Total Nacional Comunidades y Ciudades Autónomas Provincias Municipios  \
# 0  Total Nacional                              NaN        NaN        NaN
# 1  Total Nacional                              NaN        NaN        NaN
# 2  Total Nacional                              NaN        NaN        NaN
# 3  Total Nacional                              NaN        NaN        NaN
# 4  Total Nacional                              NaN        NaN        NaN
#
#      Viviendas y plazas  Periodo    Total
# 0  Viviendas turísticas  2025M11  329.764
# 1  Viviendas turísticas  2025M05  381.837
# 2  Viviendas turísticas  2024M11  376.463
# 3  Viviendas turísticas  2024M08  403.267
# 4  Viviendas turísticas  2024M02  351.389

# %%
#Numero de viviendas turísticas por municipio desde Ago 2020 a Nov 2025
dataset39363.info()
#madrid= dataset39363.loc[dataset39363 ["Municipios" == "madrid"]]
dataset39363 ["Periodo"].nunique()
dataset39363 ["Periodo"].values
dataset39363 ["Periodo"].min()
dataset39363 ["Periodo"].max()




#dataset39363 ["Provincias"].values
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 295452 entries, 0 to 295451
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Total Nacional                    295452 non-null  str
#  1   Comunidades y Ciudades Autónomas  295416 non-null  str
#  2   Provincias                        294732 non-null  str
#  3   Municipios                        292860 non-null  str
#  4   Viviendas y plazas                295452 non-null  str
#  5   Periodo                           295452 non-null  str
#  6   Total                             272708 non-null  str
# dtypes: str(7)
# memory usage: 15.8 MB
# '2025M11'

# %%
#Porcentaje de viviendas turísticas sobre el total de vivienda censada por municipios. General. No hay barrios
dataset39366 = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_vivienda\39366.csv", sep=";")
dataset39366.tail(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Porcentaje de viviendas turísticas sobre el total de vivienda censada por municipios. General. No hay barrios
# ----> 2 dataset39366 = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_vivienda\39366.csv", sep=";")
#       3 dataset39366.tail(5)
#
# NameError: name 'pd' is not defined

# %%
min=dataset39363["Periodo"].min()
max=dataset39363["Periodo"].max()
print (min,max)
print(dataset39363.shape)
# Out:
# 2020M08 2025M11
# (295452, 7)

# %%
# Población por municipio de 2021 a 2025
dataset67991 = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_vivienda\67991.csv", sep=";")
dataset67991.head(5)
min = dataset67991 ["Periodo"].min()
max = dataset67991 ["Periodo"].max()
print (min, max)
# Out:
# 2021 2025

# %%
airbnb = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_vivienda\airbnb_madrid_listings.csv")
airbnb.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              25000 non-null  int64
#  1   name                            25000 non-null  str
#  2   host_id                         25000 non-null  int64
#  3   host_name                       24903 non-null  str
#  4   neighbourhood_group             25000 non-null  str
#  5   neighbourhood                   25000 non-null  str
#  6   latitude                        25000 non-null  float64
#  7   longitude                       25000 non-null  float64
#  8   room_type                       25000 non-null  str
#  9   price                           18953 non-null  float64
#  10  minimum_nights                  25000 non-null  int64
#  11  number_of_reviews               25000 non-null  int64
# ...
