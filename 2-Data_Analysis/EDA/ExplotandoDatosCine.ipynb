# %%
import pandas as pd

# %%
oscars = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos EDA\data_cine\Oscar_Awards.csv", sep="\t")
print(oscars.shape)
oscars.info()
# Out:
# (12014, 16)
# <class 'pandas.DataFrame'>
# RangeIndex: 12014 entries, 0 to 12013
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ceremony             12014 non-null  int64
#  1   Year                 12014 non-null  str
#  2   Class                12014 non-null  str
#  3   CanonicalCategory    12014 non-null  str
#  4   Category             12014 non-null  str
#  5   NomId                11482 non-null  str
#  6   Film                 10753 non-null  str
#  7   FilmId               10753 non-null  str
#  8   Name                 10829 non-null  str
#  9   Nominees             11661 non-null  str
#  10  NomineeIds           11134 non-null  str
#  11  Winner               3476 non-null   object
#  12  Detail               3171 non-null   str
#  13  Note                 616 non-null    str
#  14  Citation             1183 non-null   str
#  15  MultifilmNomination  40 non-null     object
# ...

# %%
oscars.tail(5)
# Out:
#        Ceremony  Year    Class  \
# 12009        97  2024  SciTech
# 12010        97  2024  SciTech
# 12011        97  2024  SciTech
# 12012        97  2024  SciTech
# 12013        97  2024  SciTech
#
#                                        CanonicalCategory  \
# 12009  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 12010  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 12011  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 12012  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 12013  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
#
#                                                 Category NomId Film FilmId  \
# 12009  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...   NaN  NaN    NaN
# 12010  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...   NaN  NaN    NaN
# 12011  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...   NaN  NaN    NaN
# 12012  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...   NaN  NaN    NaN
# ...

# %%
oscars[(oscars["Class"] == "Acting") & (oscars["Year"]=="2024")].shape
# Out:
# (20, 16)

# %%
oscars["Class"].unique()
# Out:
# <StringArray>
# [    'Acting', 'Production',  'Directing',      'Title',    'Writing',
#     'Special',    'SciTech',      'Music']
# Length: 8, dtype: str

# %%
oscars[(oscars["Class"] == "Directing") & (oscars["Year"]=="2024")]
# Out:
#        Ceremony  Year      Class CanonicalCategory   Category          NomId  \
# 11916        97  2024  Directing         DIRECTING  DIRECTING  fake_nomid032
# 11917        97  2024  Directing         DIRECTING  DIRECTING  fake_nomid030
# 11918        97  2024  Directing         DIRECTING  DIRECTING  fake_nomid034
# 11919        97  2024  Directing         DIRECTING  DIRECTING  fake_nomid031
# 11920        97  2024  Directing         DIRECTING  DIRECTING  fake_nomid033
#
#                      Film      FilmId             Name         Nominees  \
# 11916               Anora  tt28607951       Sean Baker       Sean Baker
# 11917       The Brutalist   tt8999762     Brady Corbet     Brady Corbet
# 11918  A Complete Unknown  tt11563598    James Mangold    James Mangold
# 11919        Emilia Pérez  tt20221436  Jacques Audiard  Jacques Audiard
# 11920       The Substance  tt17526714  Coralie Fargeat  Coralie Fargeat
#
#       NomineeIds Winner Detail Note Citation MultifilmNomination
# ...

# %%
acting = oscars[oscars["Class"] == "Acting"]
acting.shape
# Out:
# (1855, 16)

# %%
#Cómo vienen los datos de actores/actrices
acting [acting ["Year"]=="2024"]
# Out:
#        Ceremony  Year   Class             CanonicalCategory  \
# 11876        97  2024  Acting       ACTOR IN A LEADING ROLE
# 11877        97  2024  Acting       ACTOR IN A LEADING ROLE
# 11878        97  2024  Acting       ACTOR IN A LEADING ROLE
# 11879        97  2024  Acting       ACTOR IN A LEADING ROLE
# 11880        97  2024  Acting       ACTOR IN A LEADING ROLE
# 11881        97  2024  Acting    ACTOR IN A SUPPORTING ROLE
# 11882        97  2024  Acting    ACTOR IN A SUPPORTING ROLE
# 11883        97  2024  Acting    ACTOR IN A SUPPORTING ROLE
# 11884        97  2024  Acting    ACTOR IN A SUPPORTING ROLE
# 11885        97  2024  Acting    ACTOR IN A SUPPORTING ROLE
# 11886        97  2024  Acting     ACTRESS IN A LEADING ROLE
# 11887        97  2024  Acting     ACTRESS IN A LEADING ROLE
# 11888        97  2024  Acting     ACTRESS IN A LEADING ROLE
# 11889        97  2024  Acting     ACTRESS IN A LEADING ROLE
# 11890        97  2024  Acting     ACTRESS IN A LEADING ROLE
# ...

# %%
#IMDB names. 
imdb = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_cine\name.basics.tsv\name.basics.tsv", sep="\t")
imdb.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15178050 entries, 0 to 15178049
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             str
#  1   primaryName        str
#  2   birthYear          str
#  3   deathYear          str
#  4   primaryProfession  str
#  5   knownForTitles     str
# dtypes: str(6)
# memory usage: 694.8 MB

# %%
imdb.head(5)
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934      2025
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                    primaryProfession                           knownForTitles
# 0       actor,miscellaneous,producer  tt0072308,tt0050419,tt0027125,tt0025164
# 1   actress,miscellaneous,soundtrack  tt0037382,tt0075213,tt0038355,tt0045891
# 2  actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452
# 3      actor,writer,music_department  tt0072562,tt0077975,tt0080455,tt0078723
# 4              writer,director,actor  tt0050986,tt0069467,tt0050976,tt0083922

# %%
tmdb =pd.read_csv(r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos EDA\data_cine\tmdb_5000_credits.csv")

# %%
tmdb.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   str
#  2   cast      4803 non-null   str
#  3   crew      4803 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 150.2 KB

# %%
mojo = pd.read_csv(r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos EDA\data_cine\Mojo_budget_update.csv")

# %%
mojo.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3243 entries, 0 to 3242
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         3243 non-null   str
#  1   title            3243 non-null   str
#  2   year             3243 non-null   int64
#  3   trivia           3243 non-null   str
#  4   mpaa             3082 non-null   str
#  5   release_date     3242 non-null   str
#  6   run_time         3243 non-null   str
#  7   distributor      3228 non-null   str
#  8   director         3243 non-null   str
#  9   writer           3234 non-null   str
#  10  producer         3230 non-null   str
#  11  composer         3138 non-null   str
#  12  cinematographer  3129 non-null   str
#  13  main_actor_1     3243 non-null   str
#  14  main_actor_2     3243 non-null   str
#  15  main_actor_3     3243 non-null   str
#  16  main_actor_4     3240 non-null   str
#  17  budget           3243 non-null   float64
# ...

# %%
mojo.head(5)
# Out:
#     movie_id                        title  year  \
# 0  tt0099088  Back to the Future Part III  1990
# 1  tt0099165  The Bonfire of the Vanities  1990
# 2  tt0099348           Dances with Wolves  1990
# 3  tt0099422                   Dick Tracy  1990
# 4  tt0099423                   Die Hard 2  1990
#
#                                               trivia mpaa release_date  \
# 0  Stranded in 1955, Marty McFly learns about the...  NaN       May 25
# 1  After his mistress runs over a young teen, a W...    R  December 22
# 2  Lieutenant John Dunbar, assigned to a remote w...  NaN   November 9
# 3  The comic strip detective finds his life vastl...  NaN      June 15
# 4  John McClane attempts to avert disaster as rog...  NaN       July 6
#
#       run_time                          distributor         director  \
# 0  1 hr 58 min                   Universal Pictures  Robert Zemeckis
# 1   2 hr 5 min                         Warner Bros.   Brian De Palma
# ...

# %%
mojo.columns
# Out:
# Index(['movie_id', 'title', 'year', 'trivia', 'mpaa', 'release_date',
#        'run_time', 'distributor', 'director', 'writer', 'producer', 'composer',
#        'cinematographer', 'main_actor_1', 'main_actor_2', 'main_actor_3',
#        'main_actor_4', 'budget', 'domestic', 'international', 'worldwide',
#        'genre_1', 'genre_2', 'genre_3', 'genre_4', 'html'],
#       dtype='str')

# %%
mojo["year"].max()
# Out:
# np.int64(2020)

# %%
mojo["year"].min()
# Out:
# np.int64(1990)

# %%
tmdb = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos EDA\data_cine\tmdb_5000_movies.csv")

# %%
tmdb.shape
# Out:
# (4803, 20)

# %%
tmdb.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   str
#  2   homepage              1712 non-null   str
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   str
#  5   original_language     4803 non-null   str
#  6   original_title        4803 non-null   str
#  7   overview              4800 non-null   str
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   str
#  10  production_countries  4803 non-null   str
#  11  release_date          4802 non-null   str
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   str
# ...

# %%
tmdb.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb_credits = pd.read_csv(r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos EDA\data_cine\tmdb_5000_credits.csv")

# %%
tmdb_credits.shape
# Out:
# (4803, 4)

# %%
tmdb_credits.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   str
#  2   cast      4803 non-null   str
#  3   crew      4803 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 150.2 KB

# %%
tmdb_credits.tail(5)
# Out:
#       movie_id                      title  \
# 4798      9367                El Mariachi
# 4799     72766                  Newlyweds
# 4800    231617  Signed, Sealed, Delivered
# 4801    126186           Shanghai Calling
# 4802     25975          My Date with Drew
#
#                                                    cast  \
# 4798  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 4798  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4799  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4800  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4801  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4802  [{"credit_id": "58ce021b9251415a390165d9", "de...

# %%
tmdb[tmdb ["original_language"] =="es"]
# Out:
#         budget                                             genres  \
# 492    8000000  [{"id": 35, "name": "Comedy"}, {"id": 16, "nam...
# 1462         0                      [{"id": 18, "name": "Drama"}]
# 1463  35000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 1741  24000000                     [{"id": 28, "name": "Action"}]
# 2064  22000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# 2465  19000000  [{"id": 14, "name": "Fantasy"}, {"id": 18, "na...
# 2512         0  [{"id": 10751, "name": "Family"}, {"id": 35, "...
# 2725  12806000                      [{"id": 18, "name": "Drama"}]
# 3113  10000000  [{"id": 10752, "name": "War"}, {"id": 36, "nam...
# 3149  12899867  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3524   5600000  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 3562   5500000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3596   5000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# ...

# %%
tmdb ["original_language"].unique()
# Out:
# <StringArray>
# ['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn', 'it', 'nl',
#  'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is', 'tr', 'nb', 'af', 'pl',
#  'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa', 'no', 'sl', 'ps', 'el']
# Length: 37, dtype: str

# %%
print(tmdb ["release_date"].min(), tmdb ["release_date"].max())
# Out:
# 1916-09-04 2017-02-03

# %% [markdown]
# TMDB 5000 resumen
# 4800 filas
# Información en diccionarios dentro de las columnas - Procesar
# Cubre de 1916 a 2017 - rango temporal ok (aunque me da pena no ver lo más reciente)
# Pocas pelis en proporción.

# %% [markdown]
# MOJO - Resumen
# 3243 filas
# Muy limpio.
# Cubre 1990 a 2020 - pelin escaso
# Datos de recaudación

# %% [markdown]
# El merge de ambos me queda cojete

# %%
#IMDB+TMBD
imdb_tmdb = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos EDA\data_cine\TMDB  IMDB Movies Dataset.csv")

# %%
imdb_tmdb.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 436401 entries, 0 to 436400
# Data columns (total 29 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    436401 non-null  int64
#  1   title                 436401 non-null  str
#  2   vote_average          436401 non-null  float64
#  3   vote_count            436401 non-null  int64
#  4   status                436401 non-null  str
#  5   release_date          415063 non-null  str
#  6   revenue               436401 non-null  int64
#  7   runtime               436401 non-null  int64
#  8   adult                 436401 non-null  bool
#  9   backdrop_path         185279 non-null  str
#  10  budget                436401 non-null  int64
#  11  homepage              54772 non-null   str
#  12  tconst                436401 non-null  str
#  13  original_language     436401 non-null  str
#  14  original_title        436401 non-null  str
# ...

# %%
print(imdb_tmdb ["release_date"].min())
print(imdb_tmdb ["release_date"].max())
# Out:
# 1874-12-09
# 2029-10-13

# %%
imdb_tmdb.tail(5)

# %%
imdb_tmdb ["genres"].unique
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 imdb_tmdb ["genres"].unique
#
# NameError: name 'imdb_tmdb' is not defined

# %% [markdown]
# IMDB + TMDB
# Muy buena pinta!
# 436401 filas
# 28 cols. Algunas extensibles
# Faltan los premios. Cruzar con oscars. El id es de imdb? No

# %%
import pandas as pd
tmdb_all = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos EDA\data_cine\TMDB_all_movies.csv")

# %%
tmdb_all.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1177421 entries, 0 to 1177420
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   id                       1177421 non-null  int64
#  1   title                    1177411 non-null  str
#  2   vote_average             1177421 non-null  float64
#  3   vote_count               1177421 non-null  float64
#  4   status                   1177421 non-null  str
#  5   release_date             1054468 non-null  str
#  6   revenue                  1177421 non-null  float64
#  7   runtime                  1177421 non-null  float64
#  8   budget                   1177421 non-null  float64
#  9   imdb_id                  660375 non-null   str
#  10  original_language        1177421 non-null  str
#  11  original_title           1177412 non-null  str
#  12  overview                 997625 non-null   str
# ...

# %%
print (tmdb_all ["release_date"].min())
print (tmdb_all ["release_date"].max())
# Out:
# 1874-12-09
# 2069-06-09

# %%
tmdb_all.head()
# Out:
#    id                             title  vote_average  vote_count    status  \
# 0   2                             Ariel           7.1       367.0  Released
# 1   3               Shadows in Paradise           7.3       435.0  Released
# 2   5                        Four Rooms           5.9      2810.0  Released
# 3   6                    Judgment Night           6.5       368.0  Released
# 4   8  Life in Loops (A Megacities RMX)           7.2        30.0  Released
#
#   release_date     revenue  runtime      budget    imdb_id  ...  \
# 0   1988-10-21         0.0     73.0         0.0  tt0094675  ...
# 1   1986-10-17         0.0     74.0         0.0  tt0092149  ...
# 2   1995-12-09   4257354.0     98.0   4000000.0  tt0113101  ...
# 3   1993-10-15  12136938.0    109.0  21000000.0  tt0107286  ...
# 4   2006-01-01         0.0     80.0     42000.0  tt0825671  ...
#
#                          spoken_languages  \
# 0                                   suomi
# ...

# %%
tmdb_all ["genres"].head(5)
# Out:
# 0    Comedy, Drama, Romance, Crime
# 1           Comedy, Drama, Romance
# 2                           Comedy
# 3          Action, Crime, Thriller
# 4                      Documentary
# Name: genres, dtype: str

# %% [markdown]
# TMDB All.
# Más de 1 millón de filas!
# Tiene un campo imdb_id. Interesante para cruzar con oscars
# Revisar porque está claro que tiene campos erróneos (estreno en 2069)

# %%
tmdbv11 = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos EDA\data_cine\TMDB_movie_dataset_v11.csv")

# %%
tmdbv11.info()
1150257
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1395904 entries, 0 to 1395903
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1395904 non-null  int64
#  1   title                 1395886 non-null  str
#  2   vote_average          1395904 non-null  float64
#  3   vote_count            1395904 non-null  int64
#  4   status                1395904 non-null  str
#  5   release_date          1092256 non-null  str
#  6   revenue               1395904 non-null  int64
#  7   runtime               1395904 non-null  int64
#  8   adult                 1395904 non-null  bool
#  9   backdrop_path         348606 non-null   str
#  10  budget                1395904 non-null  int64
#  11  homepage              143891 non-null   str
#  12  imdb_id               663307 non-null   str
#  13  original_language     1395904 non-null  str
#  14  original_title        1395886 non-null  str
# ...

# %%
print(tmdb_all["release_date"].min())
print(tmdb_all["release_date"].max())
# Out:
# 1874-12-09
# 2069-06-09

# %% [markdown]
# TMDBv11 - Casi la misma que la anterior.
# Algún título más. Diferencias mínimas.

# %% [markdown]
# --> Me quedo con la fusionada. Menos trabajo.
# 436401 filas
# 28 columnas.
# Merge con el id de imbd. Ver cómo lo hago

# %%
print("Budget = 0:  ", (tmdb_all["budget"] == 0).sum())
print("Revenue = 0: ", (tmdb_all["revenue"] == 0).sum())
print("Alguno de los dos: ", (tmdb_all["budget"] == 0) | (tmdb_all["revenue"] == 0)).sum()
# Out:
# Budget = 0:   1100300
# Revenue = 0:  1150257
# Alguno de los dos:  0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1177416     True
# 1177417     True
# 1177418     True
# 1177419     True
# 1177420     True
# Length: 1177421, dtype: bool
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 print("Budget = 0:  ", (tmdb_all["budget"] == 0).sum())
#       2 print("Revenue = 0: ", (tmdb_all["revenue"] == 0).sum())
# ----> 3 print("Alguno de los dos: ", (tmdb_all["budget"] == 0) | (tmdb_all["revenue"] == 0)).sum()
#
# AttributeError: 'NoneType' object has no attribute 'sum'

# %%
names = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos EDA\data_cine\name.basics.tsv\name.basics.tsv", sep="\t")

# %%
names.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15178050 entries, 0 to 15178049
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             str
#  1   primaryName        str
#  2   birthYear          str
#  3   deathYear          str
#  4   primaryProfession  str
#  5   knownForTitles     str
# dtypes: str(6)
# memory usage: 694.8 MB
