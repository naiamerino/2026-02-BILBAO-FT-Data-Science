# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Factores de éxito en el cine comercial"

# %% [markdown]
# ### TEMA

# %% [markdown]
# # Describe brevemente el tema del proyecto en Markdown
# Analizar los características de las películas exitosas en la industria del cine, combinando varias fuentes de datos (TMDb, Box Office Mojo y datasets de premios como los Oscars).
#
# El objetivo es explorar cómo diferentes variables se relacionan con el éxito comercial y crítico de una película: desde presupuesto, recaudación y ROI, hasta ratings, popularidad y premios recibidos.
#
# Se pueden estudiar varias dimensiones: comparar películas premiadas vs no premiadas, analizar la relación entre presupuesto y recaudación, explorar diferencias por género cinematográfico o país de producción, evaluar si películas con mayores ratings tienen mejor desempeño financiero, o examinar el impacto de los actores/directores más reconocidos en la performance.
#
# Otra variante interesante es incluir series temporales para ver cómo han cambiado estos factores a lo largo de los años o analizar correlaciones entre distintos tipos de premios y el rendimiento económico

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# "¿Qué factores determinan el éxito comercial y el reconocimiento crítico de una película: el presupuesto, el género, la época de estreno o los premios?"

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "“H1 — El presupuesto no es el mejor predictor del éxito comercial.”"

# %%
# Escribe más hipótesis si las hubiera en Markdown
hipotesis_2 = "“El reconocimiento de la Academia y el éxito comercial son mundos distintos.”"
hipotesis_3 = "“El género determina el techo y el suelo de una película.”"
hipotesis_4 = "El momento del estreno tiene tanto impacto como el presupuesto"
# hipotesis_5 = ""
# ...

# %% [markdown]
# Presupuesto vs Recaudación:
#
# Las películas con mayor presupuesto tienden a generar más recaudación en taquilla, pero no siempre tienen mayor ROI, lo que sugiere que la eficiencia del gasto es clave.
#
# ##### Premios vs Éxito Comercial: ##
#
# Las películas que reciben nominaciones o premios importantes (por ejemplo Oscars) muestran un mayor desempeño en recaudación y popularidad que las no premiadas, aunque puede haber excepciones dependiendo del género o año de estreno.
#
# ##### Género cinematográfico y rentabilidad:
#
# Algunos géneros (por ejemplo acción o animación) tienen una mayor recaudación media o ROI que otros (como drama o documental), independientemente del presupuesto.
#
# ##### Calificación crítica vs Recaudación:
#
# Las películas mejor valoradas por la crítica o los usuarios (ratings TMDb/IMDb) no siempre coinciden con las más rentables en taquilla, sugiriendo que el éxito crítico y comercial pueden divergir.
#
# ##### Factores combinados de éxito:
#
# La combinación de variables como presupuesto, género, premios y popularidad predice mejor el éxito financiero que cualquier factor individual por sí solo, indicando que el éxito de una película es multifactorial.

# %% [markdown]
# Bonus si me da tiempo “Las actrices ganan premios a una edad media menor que los actores.”
# “La edad media de los ganadores ha cambiado a lo largo del tiempo.”

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %% [markdown]
# IDEA 2

# %%
oscars = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_cine\Oscar_Awards.csv", sep="\t")
print(oscars.shape)
oscars.info()

# %%
acting = oscars[oscars["Class"] == "Acting"]
acting.shape

# %%
imdb = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_cine\name.basics.tsv\name.basics.tsv", sep="\t")
imdb.info()

# %%
acting.head(5)

# %%
imdb.head(5)

# %% [markdown]
# Datos de los Goya: https://www.cultura.gob.es/eu/cultura/areas/cine/datos/seleccion-festivales-premios/premios-goya.html
# Descargar e integrar cada edición
