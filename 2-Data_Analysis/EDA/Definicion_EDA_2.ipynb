# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Factores de éxito en el cine comercial"

# %% [markdown]
# ### TEMA

# %% [markdown]
# # Describe brevemente el tema del proyecto en Markdown
# Analizar los características de las películas exitosas en la industria del cine, combinando varias fuentes de datos (TMDb, Box Office Mojo y datasets de premios como los Oscars). El objetivo es explorar cómo diferentes variables se relacionan con el éxito comercial y crítico de una película: desde presupuesto, recaudación y ROI, hasta ratings, popularidad y premios recibidos. Se pueden estudiar varias dimensiones: comparar películas premiadas vs no premiadas, analizar la relación entre presupuesto y recaudación, explorar diferencias por género cinematográfico o país de producción, evaluar si películas con mayores ratings tienen mejor desempeño financiero, o examinar el impacto de los actores/directores más reconocidos en la performance. Otra variante interesante es incluir series temporales para ver cómo han cambiado estos factores a lo largo de los años o analizar correlaciones entre distintos tipos de premios y el rendimiento económico

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = "“El aumento de la vivienda turística está asociado con un incremento en el precio de la vivienda.”"

# %%
# Escribe más hipótesis si las hubiera en Markdown
hipotesis_2 = "“Las zonas con mayor presión de vivienda turística presentan precios más elevados que el resto.”"
hipotesis_3 = "“El crecimiento de la población no explica por sí solo el aumento del precio de la vivienda.”"
# hipotesis_4 = ""
# hipotesis_5 = ""
# ...

# %% [markdown]
# “Las actrices ganan premios a una edad media menor que los actores.”
# “La edad media de los ganadores ha cambiado a lo largo del tiempo.”

# %% [markdown]
# “El impacto mediático de Caitlin Clark es desproporcionado respecto a su impacto estadístico.”

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente

#Numero de viviendas turísticas por municipio desde Ago 2020 a Nov 2025
dataset39363 = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_vivienda\39363.csv", sep=";")
dataset39363.info()

#Porcentaje de viviendas turísticas sobre el total de vivienda censada por municipios. General. Hay que filtrar por CP
dataset39366 = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_vivienda\39366.csv", sep=";")
dataset39366.tail(5)
# ...
# Población por municipio de 2021 a 2025
dataset67991 = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_vivienda\67991.csv", sep=";")

#Falta la información del precio de idealista. Necesito acceso a la APi. Lo he solicitado pero...
#https://www.idealista.com/sala-de-prensa/informes-precio-vivienda/venta/madrid-comunidad/madrid-provincia/madrid/

#Anuncios actuales por barrio. PERO no tengo evolución temporal
airbnb = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_vivienda\houses_madrid.csv")

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Población por municipio de 2021 a 2025
dataset67991.head(5)

# %%
dataset39363.tail(5)

# %% [markdown]
# IDEA 2

# %%
oscars = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_cine\Oscar_Awards.csv", sep="\t")
print(oscars.shape)
oscars.info()

# %%
acting = oscars[oscars["Class"] == "Acting"]
acting.shape

# %%
imdb = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\EDA\data_cine\name.basics.tsv\name.basics.tsv", sep="\t")
imdb.info()

# %%
acting.head(5)

# %%
imdb.head(5)

# %% [markdown]
# Datos de los Goya: https://www.cultura.gob.es/eu/cultura/areas/cine/datos/seleccion-festivales-premios/premios-goya.html
# Descargar e integrar cada edición
