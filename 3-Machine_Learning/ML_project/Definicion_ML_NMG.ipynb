# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "WTA Match Predictor: un modelo de predicción de resultados en el circuito femenino de tenis"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "Modelo de machine learning entrenado sobre 44.000 partidos históricos del circuito WTA " \
"(2007-2026) para " "predecir el resultado de partidos individuales. A partir de datos públicos se construyen features temporales " \
"como forma reciente, win rate por superficie o head-to-head. Además de las métricas propias de clasificación" \
"por la naturaleza de la predicción se usará también como métrica las probabilidades de " \
"las casas de apuestas Aplicar el modelo entrenado a un caso real mediante la simulación del cuadro de Roland Garros 2026"

# %%
# Idea adicional: Clusterizar jugadoras por perfiles y añadir ese perfilado como feature

# %% [markdown]
# ### OBJETIVOS

# %% [markdown]
# Define aquí el objetivo del proyecto

# %% [markdown]
# - Construir un pipeline completo de ML aplicado a datos deportivos reales, desde la limpieza y exploración hasta la predicción, incluyendo feature engineering temporal.
# - Desarrollar un modelo de clasificación capaz de predecir el resultado de un partido WTA a partir de información disponible antes de su disputa
# - Evaluar el rendimiento del modelo usando las probabilidades implícitas de las casas de apuestas como benchmark externo, midiendo hasta qué punto un modelo basado en datos públicos puede aproximarse al mercado.
# - Aplicar el modelo entrenado a un caso real mediante la simulación del cuadro de Roland Garros 2026 con el método de Monte Carlo, obteniendo probabilidades de victoria para cada jugadora.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
# El dataset principal es el histórico de partidos de la WTA desde 2007 actualizado diariamente: "WTA Tennis 
# 2007 - 2026 Daily update"
# https://www.kaggle.com/datasets/dissfya/wta-tennis-2007-2023-daily-update
# Fuente Kaggle
# Hay otro dataset con estadísticas más completas de los partidos pero que llega sólo a 2024. Me he decidido por el 
# primero porque quiero hacer la predicción de Roland Garros 2026.
# Jeff Sackman github: https://github.com/JeffSackmann/tennis_wta

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
import pandas as pd
wta = pd.read_csv (r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos ML\wta.csv", low_memory= False)
wta.head()
# Out:
#     Tournament                 Date    Court Surface      Round  Best of  \
# 0  ASB Classic  2007-01-01 00:00:00  Outdoor    Hard  1st Round        3
# 1  ASB Classic  2007-01-01 00:00:00  Outdoor    Hard  1st Round        3
# 2  ASB Classic  2007-01-01 00:00:00  Outdoor    Hard  1st Round        3
# 3  ASB Classic  2007-01-01 00:00:00  Outdoor    Hard  1st Round        3
# 4  ASB Classic  2007-01-01 00:00:00  Outdoor    Hard  1st Round        3
#
#       Player_1      Player_2      Winner  Rank_1  Rank_2  Pts_1  Pts_2 Odd_1  \
# 0     Sun T.T.      Baker L.    Sun T.T.      81     272    332     90  1.33
# 1   Myskina A.      Dulko G.    Dulko G.      16      59   1000    401  1.22
# 2      Loit E.  Birnerova E.     Loit E.      56      84    418    324  1.72
# 3  Nakamura A.    Craybas J.  Craybas J.      57      70    405    365  1.83
# 4   Bartoli M.     Morita A.  Bartoli M.      18     180    951    152  1.16
#
#   Odd_2        Score
# 0     3     6-1 6-1
# ...

# %%
# Esta es la otra opción que creo que no usaré. Un csv por año. 
# Tiene muchos datos de estadísticos de partidos. Pero solo está hasta 2004
stats_2024= pd.read_csv(r"C:\Users\NaiaJon\Documents\Naia\BootcampDataScience\Datos ML\wta_matches_2024.csv")
stats_2024.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2024-9900   United Cup    Hard         18             I      20240101
# 1  2024-9900   United Cup    Hard         18             I      20240101
# 2  2024-9900   United Cup    Hard         18             I      20240101
# 3  2024-9900   United Cup    Hard         18             I      20240101
# 4  2024-9900   United Cup    Hard         18             I      20240101
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        299     216347          NaN          NaN  ...    27.0     13.0
# 1        297     216347          NaN          NaN  ...    47.0     28.0
# 2        295     201493          NaN          NaN  ...    82.0     47.0
# 3        293     216347          NaN          NaN  ...    27.0     18.0
# 4        291     201614          NaN          NaN  ...    72.0     51.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# ...
