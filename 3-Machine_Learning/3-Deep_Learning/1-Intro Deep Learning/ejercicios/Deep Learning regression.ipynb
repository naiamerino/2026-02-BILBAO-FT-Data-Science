# %% [markdown]
# # Regresion Basica: Predecir eficiencia de gasolina

# %% [markdown]
# Este libro usa el set de datos clasico [Auto MPG](https://archive.ics.uci.edu/ml/datasets/auto+mpg) y construye un modelo para predecir el consumo de vehiculos de 1970 y 1980. Para hacer esto proveeremos el modelo con una descripcion de muchos automoviles de ese periodo. Esta descripcion incluye atributos como: Cilindros, desplazamiento, potencia y peso.
#
# El objetivo de este ejercicio es predecir el target miles per galon (MPG), que vendría a representar las millas por galón de combustible.
#
# Este ejemplo usa el API `tf.keras` , revise [Esta Guia](https://www.tensorflow.org/guide/keras) para obtener mas detalles.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
# Out:
# 2026-01-04 19:05:34.845775: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-04 19:05:34.880627: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-04 19:05:35.744407: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /home/david/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %% [markdown]
# ## El set de Datos de MPG
#
# El set de datos esta disponible de el siguiente repositorio [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/).

# %% [markdown]
# ### Obtenga los datos
# Primero descargue el set de datos.
# keras.utils.get_file("auto-mpg.data", "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")

# %%
dataset = keras.utils.get_file("auto-mpg.data", "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
dataset
# Out:
# '/home/david/.keras/datasets/auto-mpg.data'

# %% [markdown]
# Importelo usando pandas.

# %%
column_names = ["MPG", "Cylinders", "Displacement", "Horsepower", "Weight", "Acceleration", "Model Year", "Origin", "Car name"]

# %%
df = pd.read_csv(dataset, names=column_names, delim_whitespace=True)
df
# Out:
# /tmp/ipykernel_121205/4045023703.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(dataset, names=column_names, delim_whitespace=True)
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      Model Year  Origin                   Car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### Limpia los datos
#
# Trata los missings y variables categóricas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    398 non-null    object
#  4   Weight        398 non-null    float64
#  5   Acceleration  398 non-null    float64
#  6   Model Year    398 non-null    int64
#  7   Origin        398 non-null    int64
#  8   Car name      398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement       Weight  Acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        Model Year      Origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df['Horsepower'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df['Horsepower'].astype(float)
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/pandas/core/internals/blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '?'

# %%
df[df['Horsepower']=="?"]
# Out:
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 32   25.0          4          98.0          ?  2046.0          19.0
# 126  21.0          6         200.0          ?  2875.0          17.0
# 330  40.9          4          85.0          ?  1835.0          17.3
# 336  23.6          4         140.0          ?  2905.0          14.3
# 354  34.5          4         100.0          ?  2320.0          15.8
# 374  23.0          4         151.0          ?  3035.0          20.5
#
#      Model Year  Origin              Car name
# 32           71       1            ford pinto
# 126          74       1         ford maverick
# 330          80       2  renault lecar deluxe
# 336          80       1    ford mustang cobra
# 354          81       2           renault 18i
# 374          82       1        amc concord dl

# %%
df['Horsepower'] = np.where(df['Horsepower']=="?", np.nan, df['Horsepower'])
df['Horsepower'] = df['Horsepower'].astype(float)
df['Horsepower'].fillna(df['Horsepower'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    398 non-null    float64
#  4   Weight        398 non-null    float64
#  5   Acceleration  398 non-null    float64
#  6   Model Year    398 non-null    int64
#  7   Origin        398 non-null    int64
#  8   Car name      398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB
# /tmp/ipykernel_121205/353453926.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Horsepower'].fillna(df['Horsepower'].mean(), inplace=True)

# %%
df['Origin'].value_counts()
# Out:
# Origin
# 1    249
# 3     79
# 2     70
# Name: count, dtype: int64

# %%
# df[df['Origin']==1] # Americano
# df[df['Origin']==2] # Europeo
# df[df['Origin']==3] # Japoneses

# %%
# df[df['Origin']==3]['MPG'].mean()

# %%
df['USA'] = np.where(df['Origin']==1, 1,0)
df['Europe'] = np.where(df['Origin']==2, 1,0)
df['Japan'] = np.where(df['Origin']==3, 1,0)
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin                   Car name  USA  Europe  Japan
# 0          70       1  chevrolet chevelle malibu    1       0      0
# 1          70       1          buick skylark 320    1       0      0
# 2          70       1         plymouth satellite    1       0      0
# 3          70       1              amc rebel sst    1       0      0
# 4          70       1                ford torino    1       0      0

# %%
lista_marcas = df['Car name'].str.split(expand=True, n=1)[0]
lista_marcas.value_counts()
# Out:
# 0
# ford             51
# chevrolet        43
# plymouth         31
# amc              28
# dodge            28
# toyota           25
# datsun           23
# buick            17
# pontiac          16
# volkswagen       15
# honda            13
# mercury          11
# oldsmobile       10
# mazda            10
# peugeot           8
# fiat              8
# audi              7
# vw                6
# volvo             6
# chrysler          6
# renault           5
# saab              4
# subaru            4
# opel              4
# chevy             3
# cadillac          2
# bmw               2
# mercedes-benz     2
# maxda             2
# hi                1
# toyouta           1
# chevroelt         1
# capri             1
# mercedes          1
# vokswagen         1
# triumph           1
# nissan            1
# Name: count, dtype: int64

# %%
df['Marca'] = lista_marcas.copy()
orden = df.groupby("Marca")['MPG'].mean().sort_values()
orden.sort_values()
# Out:
# Marca
# hi                9.000000
# chevroelt        16.000000
# chrysler         17.266667
# chevy            18.000000
# amc              18.246429
# mercury          19.118182
# buick            19.182353
# ford             19.694118
# cadillac         19.750000
# pontiac          20.012500
# chevrolet        20.472093
# oldsmobile       21.100000
# volvo            21.116667
# plymouth         21.703226
# dodge            22.060714
# toyouta          23.000000
# mercedes-benz    23.250000
# peugeot          23.687500
# bmw              23.750000
# saab             23.900000
# capri            25.000000
# mercedes         25.400000
# opel             25.750000
# maxda            26.050000
# audi             26.714286
# toyota           28.372000
# fiat             28.912500
# volkswagen       29.106667
# vokswagen        29.800000
# subaru           30.525000
# mazda            30.860000
# datsun           31.113043
# renault          32.880000
# honda            33.761538
# triumph          35.000000
# nissan           36.000000
# vw               39.016667
# Name: MPG, dtype: float64

# %%
df['Marca'] = lista_marcas.copy()
df["Consumo Marca"] = df.groupby("Marca")["MPG"].transform("mean")

# %%
df
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin                   Car name  USA  Europe  Japan  \
# 0            70       1  chevrolet chevelle malibu    1       0      0
# 1            70       1          buick skylark 320    1       0      0
# 2            70       1         plymouth satellite    1       0      0
# 3            70       1              amc rebel sst    1       0      0
# 4            70       1                ford torino    1       0      0
# ..          ...     ...                        ...  ...     ...    ...
# 393          82       1            ford mustang gl    1       0      0
# 394          82       2                  vw pickup    0       1      0
# 395          82       1              dodge rampage    1       0      0
# 396          82       1                ford ranger    1       0      0
# 397          82       1                 chevy s-10    1       0      0
#
#          Marca  Consumo Marca
# 0    chevrolet      20.472093
# 1        buick      19.182353
# 2     plymouth      21.703226
# 3          amc      18.246429
# 4         ford      19.694118
# ..         ...            ...
# 393       ford      19.694118
# 394         vw      39.016667
# 395      dodge      22.060714
# 396       ford      19.694118
# 397      chevy      18.000000
#
# [398 rows x 14 columns]

# %%
len(orden)
# Out:
# 37

# %%
le = pd.DataFrame(np.arange(1,38), columns=["le_marca"], index=orden.index)
le
# Out:
#                le_marca
# Marca
# hi                    1
# chevroelt             2
# chrysler              3
# chevy                 4
# amc                   5
# mercury               6
# buick                 7
# ford                  8
# cadillac              9
# pontiac              10
# chevrolet            11
# oldsmobile           12
# volvo                13
# plymouth             14
# dodge                15
# toyouta              16
# mercedes-benz        17
# peugeot              18
# bmw                  19
# saab                 20
# capri                21
# mercedes             22
# opel                 23
# maxda                24
# audi                 25
# toyota               26
# fiat                 27
# volkswagen           28
# vokswagen            29
# subaru               30
# mazda                31
# datsun               32
# renault              33
# honda                34
# triumph              35
# nissan               36
# vw                   37

# %%
df = pd.merge(df, le, left_on="Marca", right_index=True)
df
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin                   Car name  USA  Europe  Japan  \
# 0            70       1  chevrolet chevelle malibu    1       0      0
# 1            70       1          buick skylark 320    1       0      0
# 2            70       1         plymouth satellite    1       0      0
# 3            70       1              amc rebel sst    1       0      0
# 4            70       1                ford torino    1       0      0
# ..          ...     ...                        ...  ...     ...    ...
# 393          82       1            ford mustang gl    1       0      0
# 394          82       2                  vw pickup    0       1      0
# 395          82       1              dodge rampage    1       0      0
# 396          82       1                ford ranger    1       0      0
# 397          82       1                 chevy s-10    1       0      0
#
#          Marca  Consumo Marca  le_marca
# 0    chevrolet      20.472093        11
# 1        buick      19.182353         7
# 2     plymouth      21.703226        14
# 3          amc      18.246429         5
# 4         ford      19.694118         8
# ..         ...            ...       ...
# 393       ford      19.694118         8
# 394         vw      39.016667        37
# 395      dodge      22.060714        15
# 396       ford      19.694118         8
# 397      chevy      18.000000         4
#
# [398 rows x 15 columns]

# %% [markdown]
# ### Divide los datos en train y test
#
# Ahora divida el set de datos en un set de entrenamiento y otro de pruebas. 80% para entrenamiento
#
# Usaremos el set de pruebas en la evaluacion final de nuestro modelo.
#
# NOTA: El resultado tienen que ser dos datasets

# %%
# df.drop(columns=["Car name", "Origin", "Marca"], inplace=True)
df.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin                   Car name  USA  Europe  Japan  \
# 0          70       1  chevrolet chevelle malibu    1       0      0
# 1          70       1          buick skylark 320    1       0      0
# 2          70       1         plymouth satellite    1       0      0
# 3          70       1              amc rebel sst    1       0      0
# 4          70       1                ford torino    1       0      0
#
#        Marca  Consumo Marca  le_marca
# 0  chevrolet      20.472093        11
# 1      buick      19.182353         7
# 2   plymouth      21.703226        14
# 3        amc      18.246429         5
# 4       ford      19.694118         8

# %%
df.drop(columns=["Car name","Marca"],inplace=True)

# %%
df.shape
# Out:
# (398, 13)

# %%
train = df.sample(frac=0.8, random_state=42)
test = df.drop(train.index)

# %%
print(train.shape)
print(test.shape)
# Out:
# (318, 13)
# (80, 13)

# %% [markdown]
# ### Inspecciona los datos
#
# Revise rapidamente la distribucion conjunta del dataset de entrenamiento mediante un grid de gráficos

# %%
sns.pairplot(df)

# %% [markdown]
# Tambien revise las estadisticas generales:

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.199187   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   95.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year      Origin         USA      Europe  \
# count    398.000000  398.000000  398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864    0.625628    0.175879
# std        2.757689    3.697627    0.802055    0.484569    0.381197
# min        8.000000   70.000000    1.000000    0.000000    0.000000
# 25%       13.825000   73.000000    1.000000    0.000000    0.000000
# 50%       15.500000   76.000000    1.000000    1.000000    0.000000
# 75%       17.175000   79.000000    2.000000    1.000000    0.000000
# max       24.800000   82.000000    3.000000    1.000000    1.000000
#
#             Japan  Consumo Marca    le_marca
# count  398.000000     398.000000  398.000000
# mean     0.198492      23.514573   16.381910
# std      0.399367       5.158094    9.771179
# min      0.000000       9.000000    1.000000
# 25%      0.000000      19.694118    8.000000
# 50%      0.000000      21.703226   14.000000
# 75%      0.000000      28.372000   26.000000
# max      1.000000      39.016667   37.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Separa las features del target
#
# Separe el target de las features.

# %%
X_train = train.drop(columns="MPG")
X_test = test.drop(columns="MPG")
y_train = train['MPG']
y_test = test['MPG']

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (318, 12)
# (80, 12)
# (318,)
# (80,)

# %% [markdown]
# ### Estandariza los datos

# %% [markdown]
# Es una buena práctica estandarizar funciones que utilizan diferentes escalas y rangos. Aunque el modelo podría converger sin estandarizar, dificulta el entrenamiento y hace que el modelo resultante dependa de la elección de las unidades utilizadas en la entrada.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_trian_scal = scaler.fit_transform(X_train)
X_test_scal = scaler.transform(X_test)

# %% [markdown]
# Estos datos estandarizados es lo que usaremos para entrenar el modelo.

# %% [markdown]
# ## El modelo

# %% [markdown]
# ### Construye el modelo
#
# Construyamos nuestro modelo. Aquí, utilizaremos un modelo `secuencial` con dos capas ocultas densamente conectadas y una capa de salida que devuelve un único valor continuo.
#
# Por tanto, tendrá tres capas. Una de entrada con activación relu. Otra hidden layer con activación relu y la de salida de regresión, que se compondrá de una única neurona. Pon las neuronas que consideres para las dos primeras capas.
#
# Para el compile utiliza un loss='mse'.
#
# optimizer = `tf.keras.optimizers.RMSprop(0.001)`
#
# Y en metrics añade en una lista el `mae` y `mse`.

# %%
X_train.shape[1:]
# Out:
# (12,)

# %%
model = keras.Sequential([
    keras.layers.Dense(64, activation="relu", input_shape=X_train.shape[1:]),
    keras.layers.Dense(16,activation="relu"),
    keras.layers.Dense(1)
])

model.compile(
    loss="mse",
    optimizer= keras.optimizers.RMSprop(0.001),
    metrics=['mae','mse']
)
# Out:
# /home/david/The_Bridge/2025-10-DS-FT-BIL/2025-OCT-BILBAO-FT-Data-Science/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1767550060.240538  121205 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ### Inspeccione el modelo
#
# Use el método `.summary` para imprimir una descripción simple del modelo

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │         1,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,889 (7.38 KB)
#  Trainable params: 1,889 (7.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
10*64 + 64
# Out:
# 704

# %%
64*16 + 16
# Out:
# 1040

# %% [markdown]
# ### Entrenar el modelo
#
# Entrene el modelo para 1000 epochs y guarda los resultados del entrenamiento en una variable llamada `history`.
# Emplea en el entrenamiento un 20% de los datos para validación, mediante el argumento `validation_split`.
#
# NOTA: recuerda usar los datos normalizados.

# %%
X_trian_scal.shape
# Out:
# (318, 12)

# %%
early_stopping = keras.callbacks.EarlyStopping(patience=10)
history = model.fit(X_trian_scal, y_train, epochs=1000, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss:
1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53.0966 - mae: 5.7830 - mse: 53.0966 - val_loss: 50.3826 - val_mae: 5.6363 - val_mse: 50.3826
# Epoch 22/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 42.2001 - mae: 5.1768 - mse: 42.2001 - val_loss: 40.8912 - val_mae: 5.0471 - val_mse: 40.8912
# Epoch 23/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.4496 - mae: 4.6395 - mse: 33.4496 - val_loss: 33.6800 - val_mae: 4.5261 - val_mse: 33.6800
# Epoch 24/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.5819 - mae: 4.1441 - mse: 26.5819 - val_loss: 28.2940 - val_mae: 4.0772 - val_mse: 28.2940
# Epoch 25/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.7197 - mae: 3.7455 - mse: 21.7197 - val_loss: 24.3758 - val_mae: 3.6543 - val_mse: 24.3758
# Epoch 26/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.3292 - mae: 3.4470 - mse: 18.3292 - val_loss: 22.0694 - val_mae: 3.4012 - val_mse: 22.0694
# Epoch 27/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.5761 - mae: 3.2301 - mse: 16.5761 - val_loss: 20.9981 - val_mae: 3.2735 - val_mse: 20.9981
# Epoch 28/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.1710 - mae: 3.0588 - mse: 15.1710 - val_loss: 20.1022 - val_mae: 3.1393 - val_mse: 20.1022
# Epoch 29/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.3108 - mae: 2.9784 - mse: 14.3108 - val_loss: 19.6547 - val_mae: 3.1071 - val_mse: 19.6547
# Epoch 30/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.4549 - mae: 2.8691 - mse: 13.4549 - val_loss: 18.9966 - val_mae: 3.0272 - val_mse: 18.9966
# Epoch 31/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.8582 - mae: 2.8190 - mse: 12.8582 - val_loss: 18.5886 - val_mae: 2.9774 - val_mse: 18.5886
# Epoch 32/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.1600 - mae: 2.7350 - mse: 12.1600 - val_loss: 17.9601 - val_mae: 2.8859 - val_mse: 17.9601
# Epoch 33/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.7297 - mae: 2.7014 - mse: 11.7297 - val_loss: 18.4470 - val_mae: 2.9582 - val_mse: 18.4470
# Epoch 34/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.2963 - mae: 2.6536 - mse: 11.2963 - val_loss: 18.3837 - val_mae: 2.9379 - val_mse: 18.3837
# Epoch 35/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.8182 - mae: 2.5744 - mse: 10.8182 - val_loss: 17.3441 - val_mae: 2.8422 - val_mse: 17.3441
# Epoch 36/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.3942 - mae: 2.5215 - mse: 10.3942 - val_loss: 17.3650 - val_mae: 2.8524 - val_mse: 17.3650
# Epoch 37/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.0442 - mae: 2.4792 - mse: 10.0442 - val_loss: 16.6739 - val_mae: 2.7665 - val_mse: 16.6739
# Epoch 38/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7290 - mae: 2.4410 - mse: 9.7290 - val_loss: 16.4408 - val_mae: 2.7476 - val_mse: 16.4408
# Epoch 39/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4994 - mae: 2.3985 - mse: 9.4994 - val_loss: 16.4524 - val_mae: 2.7492 - val_mse: 16.4524
# Epoch 40/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3041 - mae: 2.3733 - mse: 9.3041 - val_loss: 15.8998 - val_mae: 2.6988 - val_mse: 15.8998
# Epoch 41/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9306 - mae: 2.3305 - mse: 8.9306 - val_loss: 15.9166 - val_mae: 2.7123 - val_mse: 15.9166
# Epoch 42/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7717 - mae: 2.3080 - mse: 8.7717 - val_loss: 15.4856 - val_mae: 2.6833 - val_mse: 15.4856
# Epoch 43/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5396 - mae: 2.2796 - mse: 8.5396 - val_loss: 15.3837 - val_mae: 2.6393 - val_mse: 15.3837
# Epoch 44/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3106 - mae: 2.2320 - mse: 8.3106 - val_loss: 15.1419 - val_mae: 2.6155 - val_mse: 15.1419
# Epoch 45/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2853 - mae: 2.2379 - mse: 8.2853 - val_loss: 14.9661 - val_mae: 2.6170 - val_mse: 14.9661
# Epoch 46/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0212 - mae: 2.2103 - mse: 8.0212 - val_loss: 14.9813 - val_mae: 2.6046 - val_mse: 14.9813
# Epoch 47/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8108 - mae: 2.1891 - mse: 7.8108 - val_loss: 14.3820 - val_mae: 2.5495 - val_mse: 14.3820
# Epoch 48/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7807 - mae: 2.1780 - mse: 7.7807 - val_loss: 14.4131 - val_mae: 2.5757 - val_mse: 14.4131
# Epoch 49/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5509 - mae: 2.1362 - mse: 7.5509 - val_loss: 14.0075 - val_mae: 2.5097 - val_mse: 14.0075
# Epoch 50/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5944 - mae: 2.1312 - mse: 7.5944 - val_loss: 14.0716 - val_mae: 2.4980 - val_mse: 14.0716
# Epoch 51/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3527 - mae: 2.0990 - mse: 7.3527 - val_loss: 14.2377 - val_mae: 2.5181 - val_mse: 14.2377
# Epoch 52/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2118 - mae: 2.0657 - mse: 7.2118 - val_loss: 13.7307 - val_mae: 2.4719 - val_mse: 13.7307
# Epoch 53/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1352 - mae: 2.0513 - mse: 7.1352 - val_loss: 13.3014 - val_mae: 2.4386 - val_mse: 13.3014
# Epoch 54/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1746 - mae: 2.0556 - mse: 7.1746 - val_loss: 13.4443 - val_mae: 2.4374 - val_mse: 13.4443
# Epoch 55/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0006 - mae: 2.0161 - mse: 7.0006 - val_loss: 13.4956 - val_mae: 2.4426 - val_mse: 13.4956
# Epoch 56/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8122 - mae: 1.9897 - mse: 6.8122 - val_loss: 13.0670 - val_mae: 2.4292 - val_mse: 13.0670
# Epoch 57/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8442 - mae: 2.0125 - mse: 6.8442 - val_loss: 12.9162 - val_mae: 2.3954 - val_mse: 12.9162
# Epoch 58/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6567 - mae: 1.9611 - mse: 6.6567 - val_loss: 12.6154 - val_mae: 2.3609 - val_mse: 12.6154
# Epoch 59/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7308 - mae: 1.9583 - mse: 6.7308 - val_loss: 12.9886 - val_mae: 2.3744 - val_mse: 12.9886
# Epoch 60/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5404 - mae: 1.9377 - mse: 6.5404 - val_loss: 12.6073 - val_mae: 2.3330 - val_mse: 12.6073
# Epoch 61/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5657 - mae: 1.9229 - mse: 6.5657 - val_loss: 12.3935 - val_mae: 2.3186 - val_mse: 12.3935
# Epoch 62/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3202 - mae: 1.8961 - mse: 6.3202 - val_loss: 12.8943 - val_mae: 2.3699 - val_mse: 12.8943
# Epoch 63/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4403 - mae: 1.8835 - mse: 6.4403 - val_loss: 12.4326 - val_mae: 2.3393 - val_mse: 12.4326
# Epoch 64/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6
1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4630 - mae: 1.7197 - mse: 5.4630 - val_loss: 11.3075 - val_mae: 2.1637 - val_mse: 11.3075
# Epoch 87/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5259 - mae: 1.7338 - mse: 5.5259 - val_loss: 11.0641 - val_mae: 2.1251 - val_mse: 11.0641
# Epoch 88/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4081 - mae: 1.7032 - mse: 5.4081 - val_loss: 11.2437 - val_mae: 2.1331 - val_mse: 11.2437
# Epoch 89/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3773 - mae: 1.7143 - mse: 5.3773 - val_loss: 11.4808 - val_mae: 2.1648 - val_mse: 11.4808
# Epoch 90/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4127 - mae: 1.7118 - mse: 5.4127 - val_loss: 10.8716 - val_mae: 2.0782 - val_mse: 10.8716
# Epoch 91/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4560 - mae: 1.7182 - mse: 5.4560 - val_loss: 10.8697 - val_mae: 2.0934 - val_mse: 10.8697
# Epoch 92/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4742 - mae: 1.7257 - mse: 5.4742 - val_loss: 11.0230 - val_mae: 2.1259 - val_mse: 11.0230
# Epoch 93/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4692 - mae: 1.7067 - mse: 5.4692 - val_loss: 11.0108 - val_mae: 2.1003 - val_mse: 11.0108
# Epoch 94/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4333 - mae: 1.6994 - mse: 5.4333 - val_loss: 10.8714 - val_mae: 2.0933 - val_mse: 10.8714
# Epoch 95/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4766 - mae: 1.7099 - mse: 5.4766 - val_loss: 10.8448 - val_mae: 2.0960 - val_mse: 10.8448
# Epoch 96/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4341 - mae: 1.7154 - mse: 5.4341 - val_loss: 10.8103 - val_mae: 2.0933 - val_mse: 10.8103
# Epoch 97/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4432 - mae: 1.7036 - mse: 5.4432 - val_loss: 10.8221 - val_mae: 2.1227 - val_mse: 10.8221
# Epoch 98/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4074 - mae: 1.6986 - mse: 5.4074 - val_loss: 10.8551 - val_mae: 2.1272 - val_mse: 10.8551
# Epoch 99/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2896 - mae: 1.6912 - mse: 5.2896 - val_loss: 10.6872 - val_mae: 2.0686 - val_mse: 10.6872
# Epoch 100/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3147 - mae: 1.6989 - mse: 5.3147 - val_loss: 10.8755 - val_mae: 2.0895 - val_mse: 10.8755
# Epoch 101/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2655 - mae: 1.6848 - mse: 5.2655 - val_loss: 11.0185 - val_mae: 2.1149 - val_mse: 11.0185
# Epoch 102/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2826 - mae: 1.6702 - mse: 5.2826 - val_loss: 11.0373 - val_mae: 2.1110 - val_mse: 11.0373
# Epoch 103/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2074 - mae: 1.6754 - mse: 5.2074 - val_loss: 10.8996 - val_mae: 2.0961 - val_mse: 10.8996
# Epoch 104/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1665 - mae: 1.6689 - mse: 5.1665 - val_loss: 11.0407 - val_mae: 2.1107 - val_mse: 11.0407
# Epoch 105/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2250 - mae: 1.6673 - mse: 5.2250 - val_loss: 10.7917 - val_mae: 2.0728 - val_mse: 10.7917
# Epoch 106/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3229 - mae: 1.7072 - mse: 5.3229 - val_loss: 10.8413 - val_mae: 2.1158 - val_mse: 10.8413
# Epoch 107/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2019 - mae: 1.6619 - mse: 5.2019 - val_loss: 10.7928 - val_mae: 2.0782 - val_mse: 10.7928
# Epoch 108/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5
100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1635 - mae: 1.6724 - mse: 5.1635 - val_loss: 11.1017 - val_mae: 2.1415 - val_mse: 11.1017
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1836 - mae: 1.6620 - mse: 5.1836 - val_loss: 10.9661 - val_mae: 2.1426 - val_mse: 10.9661
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2693 - mae: 1.6922 - mse: 5.2693 - val_loss: 10.9159 - val_mae: 2.0896 - val_mse: 10.9159
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1417 - mae: 1.6615 - mse: 5.1417 - val_loss: 10.8624 - val_mae: 2.0815 - val_mse: 10.8624
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2097 - mae: 1.6825 - mse: 5.2097 - val_loss: 10.8970 - val_mae: 2.0756 - val_mse: 10.8970
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1650 - mae: 1.6587 - mse: 5.1650 - val_loss: 10.8100 - val_mae: 2.1154 - val_mse: 10.8100
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2548 - mae: 1.6802 - mse: 5.2548 - val_loss: 10.8124 - val_mae: 2.0928 - val_mse: 10.8124
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1120 - mae: 1.6648 - mse: 5.1120 - val_loss: 10.7013 - val_mae: 2.0574 - val_mse: 10.7013
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1885 - mae: 1.6871 - mse: 5.1885 - val_loss: 10.7300 - val_mae: 2.0711 - val_mse: 10.7300
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0157 - mae: 1.6445 - mse: 5.0157 - val_loss: 10.6238 - val_mae: 2.0836 - val_mse: 10.6238
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0500 - mae: 1.6502 - mse: 5.0500 - val_loss: 10.6296 - val_mae: 2.0628 - val_mse: 10.6296
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9613 - mae: 1.6519 - mse: 4.9613 - val_loss: 11.0105 - val_mae: 2.1062 - val_mse: 11.0105
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0893 - mae: 1.6716 - mse: 5.0893 - val_loss: 10.5410 - val_mae: 2.0751 - val_mse: 10.5410
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0789 - mae: 1.6616 - mse: 5.0789 - val_loss: 10.5625 - val_mae: 2.0635 - val_mse: 10.5625
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0481 - mae: 1.6565 - mse: 5.0481 - val_loss: 10.7025 - val_mae: 2.0846 - val_mse: 10.7025
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0852 - mae: 1.6528 - mse: 5.0852 - val_loss: 10.8207 - val_mae: 2.1046 - val_mse: 10.8207
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9572 - mae: 1.6550 - mse: 4.9572 - val_loss: 10.5013 - val_mae: 2.0324 - val_mse: 10.5013
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0138 - mae: 1.6449 - mse: 5.0138 - val_loss: 10.5350 - val_mae: 2.0316 - val_mse: 10.5350
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0249 - mae: 1.6589 - mse: 5.0249 - val_loss: 10.5381 - val_mae: 2.0552 - val_mse: 10.5381
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9091 - mae: 1.6345 - mse: 4.9091 - val_loss: 10.5024 - val_mae: 2.0626 - val_mse: 10.5024
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0379 - mae: 1.6712 - mse: 5.0379 - val_loss: 10.7019 - val_mae: 2.0890 - val_mse: 10.7019
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0072 - mae: 1.6480 - mse: 5.0072 - val_loss: 10.5710 - val_mae: 2.0582 - val_mse: 10.5710
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9729 - mae: 1.6353 - mse: 4.9729 - val_loss: 10.5346 - val_mae: 2.0302 - val_mse: 10.5346
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9901 - mae: 1.6633 - mse: 4.9901 - val_loss: 10.8281 - val_mae: 2.0905 - val_mse: 10.8281
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9009 - mae: 1.6323 - mse: 4.9009 - val_loss: 10.5145 - val_mae: 2.0486 - val_mse: 10.5145
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0653 - mae: 1.6545 - mse: 5.0653 - val_loss: 10.7711 - val_mae: 2.0694 - val_mse: 10.7711
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9747 - mae: 1.6307 - mse: 4.9747 - val_loss: 10.7903 - val_mae: 2.0860 - val_mse: 10.7903
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0310 - mae: 1.6603 - mse: 5.0310 - val_loss: 10.7334 - val_mae: 2.0840 - val_mse: 10.7334
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8553 - mae: 1.6263 - mse: 4.8553 - val_loss: 10.7519 - val_mae: 2.0605 - val_mse: 10.7519
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9187 - mae: 1.6373 - mse: 4.9187 - val_loss: 10.6566 - val_mae: 2.0393 - val_mse: 10.6566
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8755 - mae: 1.6152 - mse: 4.8755 - val_loss: 10.7686 - val_mae: 2.0904 - val_mse: 10.7686
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8952 - mae: 1.6376 - mse: 4.8952 - val_loss: 10.6394 - val_mae: 2.0852 - val_mse: 10.6394
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7734 - mae: 1.6183 - mse: 4.7734 - val_loss: 11.0991 - val_mae: 2.1091 - val_mse: 11.0991
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8173 - mae: 1.6181 - mse: 4.8173 - val_loss: 10.7395 - val_mae: 2.0422 - val_mse: 10.7395
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9898 - mae: 1.6496 - mse: 4.9898 - val_loss: 10.7849 - val_mae: 2.0709 - val_mse: 10.7849
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9088 - mae: 1.6381 - mse: 4.9088 - val_loss: 10.7052 - val_mae: 2.0680 - val_mse: 10.7052
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8022 - mae: 1.6240 - mse: 4.8022 - val_loss: 10.7514 - val_mae: 2.0727 - val_mse: 10.7514
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8632 - mae: 1.6401 - mse: 4.8632 - val_loss: 10.6360 - val_mae: 2.0687 - val_mse: 10.6360
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8394 - mae: 1.6157 - mse: 4.8394 - val_loss: 10.8035 - val_mae: 2.1062 - val_mse: 10.8035
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8243 - mae: 1.6339 - mse: 4.8243 - val_loss: 10.5911 - val_mae: 2.0223 - val_mse: 10.5911
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8363 - mae: 1.6193 - mse: 4.8363 - val_loss: 10.7284 - val_mae: 2.0818 - val_mse: 10.7284
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8571 - mae: 1.6297 - mse: 4.8571 - val_loss: 10.7348 - val_mae: 2.0812 - val_mse: 10.7348
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7961 - mae: 1.6301 - mse: 4.7961 - val_loss: 10.5286 - val_mae: 2.0537 - val_mse: 10.5286
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8142 - mae: 1.6364 - mse: 4.8142 - val_loss: 10.5448 - val_mae: 2.0365 - val_mse: 10.5448
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9029 - mae: 1.6330 - mse: 4.9029 - val_loss: 10.7239 - val_mae: 2.0713 - val_mse: 10.7239
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7760 - mae: 1.6135 - mse: 4.7760 - val_loss: 10.6024 - val_mae: 2.0428 - val_mse: 10.6024
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7381 - mae: 1.6031 - mse: 4.7381 - val_loss: 10.4042 - val_mae: 2.0329 - val_mse: 10.4042
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7968 - mae: 1.6256 - mse: 4.7968 - val_loss: 10.5073 - val_mae: 2.0241 - val_mse: 10.5073
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8626 - mae: 1.6160 - mse: 4.8626 - val_loss: 10.6424 - val_mae: 2.0761 - val_mse: 10.6424
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7667 - mae: 1.6089 - mse: 4.7667 - val_loss: 10.5366 - val_mae: 2.0256 - val_mse: 10.5366
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8127 - mae: 1.6152 - mse: 4.8127 - val_loss: 10.6099 - val_mae: 2.0520 - val_mse: 10.6099
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7310 - mae: 1.6137 - mse: 4.7310 - val_loss: 11.0971 - val_mae: 2.0959 - val_mse: 11.0971
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8284 - mae: 1.6306 - mse: 4.8284 - val_loss: 10.4693 - val_mae: 2.0157 - val_mse: 10.4693
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8492 - mae: 1.6309 - mse: 4.8492 - val_loss: 10.5202 - val_mae: 2.0387 - val_mse: 10.5202
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7323 - mae: 1.6208 - mse: 4.7323 - val_loss: 10.5974 - val_mae: 2.0417 - val_mse: 10.5974
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6970 - mae: 1.5967 - mse: 4.6970 - val_loss: 10.4452 - val_mae: 2.0150 - val_mse: 10.4452
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7909 - mae: 1.6055 - mse: 4.7909 - val_loss: 10.5161 - val_mae: 2.0444 - val_mse: 10.5161
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7632 - mae: 1.6275 - mse: 4.7632 - val_loss: 10.6948 - val_mae: 2.0658 - val_mse: 10.6948
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7490 - mae: 1.6144 - mse: 4.7490 - val_loss: 10.6901 - val_mae: 2.0515 - val_mse: 10.6901
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6658 - mae: 1.6025 - mse: 4.6658 - val_loss: 10.6149 - val_mae: 2.0725 - val_mse: 10.6149
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7045 - mae: 1.6076 - mse: 4.7045 - val_loss: 10.5057 - val_mae: 2.0202 - val_mse: 10.5057
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7279 - mae: 1.6110 - mse: 4.7279 - val_loss: 10.6362 - val_mae: 2.0613 - val_mse: 10.6362
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6634 - mae: 1.6112 - mse: 4.6634 - val_loss: 10.3854 - val_mae: 2.0066 - val_mse: 10.3854
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6860 - mae: 1.6209 - mse: 4.6860 - val_loss: 10.3590 - val_mae: 2.0044 - val_mse: 10.3590
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7530 - mae: 1.6258 - mse: 4.7530 - val_loss: 10.4468 - val_mae: 2.0346 - val_mse: 10.4468
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5678 - mae: 1.5874 - mse: 4.5678 - val_loss: 10.8428 - val_mae: 2.0633 - val_mse: 10.8428
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6742 - mae: 1.6037 - mse: 4.6742 - val_loss: 10.4850 - val_mae: 2.0378 - val_mse: 10.4850
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6342 - mae: 1.6068 - mse: 4.6342 - val_loss: 10.7049 - val_mae: 2.0462 - val_mse: 10.7049
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5913 - mae: 1.5768 - mse: 4.5913 - val_loss: 10.7134 - val_mae: 2.0708 - val_mse: 10.7134
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6511 - mae: 1.5950 - mse: 4.6511 - val_loss: 10.4810 - val_mae: 2.0186 - val_mse: 10.4810
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8232 - mae: 1.6254 - mse: 4.8232 - val_loss: 10.4038 - val_mae: 2.0143 - val_mse: 10.4038
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6164 - mae: 1.5951 - mse: 4.6164 - val_loss: 10.3986 - val_mae: 2.0032 - val_mse: 10.3986
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6208 - mae: 1.5959 - mse: 4.6208 - val_loss: 10.5188 - val_mae: 2.0476 - val_mse: 10.5188
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6601 - mae: 1.6035 - mse: 4.6601 - val_loss: 10.6013 - val_mae: 2.0371 - val_mse: 10.6013
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5102 - mae: 1.5829 - mse: 4.5102 - val_loss: 10.3489 - val_mae: 2.0168 - val_mse: 10.3489
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5839 - mae: 1.5959 - mse: 4.5839 - val_loss: 10.5850 - val_mae: 2.0611 - val_mse: 10.5850
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6498 - mae: 1.5973 - mse: 4.6498 - val_loss: 10.4922 - val_mae: 2.0139 - val_mse: 10.4922
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5873 - mae: 1.6001 - mse: 4.5873 - val_loss: 10.5916 - val_mae: 2.0686 - val_mse: 10.5916
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6594 - mae: 1.6094 - mse: 4.6594 - val_loss: 10.4271 - val_mae: 2.0170 - val_mse: 10.4271
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6091 - mae: 1.6149 - mse: 4.6091 - val_loss: 10.5820 - val_mae: 2.0655 - val_mse: 10.5820
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5263 - mae: 1.5907 - mse: 4.5263 - val_loss: 10.6279 - val_mae: 2.0581 - val_mse: 10.6279
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7437 - mae: 1.6172 - mse: 4.7437 - val_loss: 10.4934 - val_mae: 2.0403 - val_mse: 10.4934
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5540 - mae: 1.5932 - mse: 4.5540 - val_loss: 10.3441 - val_mae: 2.0047 - val_mse: 10.3441
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5473 - mae: 1.5758 - mse: 4.5473 - val_loss: 10.4043 - val_mae: 2.0113 - val_mse: 10.4043
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4708 - mae: 1.5884 - mse: 4.4708 - val_loss: 10.9356 - val_mae: 2.0790 - val_mse: 10.9356
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6982 - mae: 1.6263 - mse: 4.6982 - val_loss: 10.5452 - val_mae: 2.0460 - val_mse: 10.5452
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4961 - mae: 1.5666 - mse: 4.4961 - val_loss: 10.5159 - val_mae: 2.0378 - val_mse: 10.5159
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5788 - mae: 1.5998 - mse: 4.5788 - val_loss: 10.4151 - val_mae: 2.0369 - val_mse: 10.4151
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5729 - mae: 1.5853 - mse: 4.5729 - val_loss: 10.4961 - val_mae: 2.0573 - val_mse: 10.4961
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5090 - mae: 1.5872 - mse: 4.5090 - val_loss: 10.6443 - val_mae: 2.0607 - val_mse: 10.6443
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6827 - mae: 1.6119 - mse: 4.6827 - val_loss: 10.4476 - val_mae: 2.0348 - val_mse: 10.4476
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5188 - mae: 1.5835 - mse: 4.5188 - val_loss: 10.4061 - val_mae: 2.0122 - val_mse: 10.4061
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4536 - mae: 1.5552 - mse: 4.4536 - val_loss: 10.7702 - val_mae: 2.0552 - val_mse: 10.7702
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5541 - mae: 1.6061 - mse: 4.5541 - val_loss: 10.5010 - val_mae: 2.0247 - val_mse: 10.5010
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4797 - mae: 1.5769 - mse: 4.4797 - val_loss: 10.6233 - val_mae: 2.0352 - val_mse: 10.6233
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6257 - mae: 1.6046 - mse: 4.6257 - val_loss: 10.4789 - val_mae: 2.0351 - val_mse: 10.4789
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4750 - mae: 1.5650 - mse: 4.4750 - val_loss: 10.4345 - val_mae: 2.0179 - val_mse: 10.4345
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4358 - mae: 1.5764 - mse: 4.4358 - val_loss: 10.7912 - val_mae: 2.0957 - val_mse: 10.7912
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4834 - mae: 1.5814 - mse: 4.4834 - val_loss: 10.5630 - val_mae: 2.0543 - val_mse: 10.5630
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4449 - mae: 1.5732 - mse: 4.4449 - val_loss: 10.3142 - val_mae: 2.0007 - val_mse: 10.3142

# %%
pd.DataFrame(history2.history)[['loss','val_loss']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ¿Alguna conclusión respecto a este gráfico?

# %% [markdown]
# Earlystopping me ha ayudado a detener el entrenamiento para no caer en overfitting, también para ahorrar recursos innecesarios.

# %% [markdown]
# Interpreta el gráfico

# %% [markdown]
# Veamos qué tan bien generaliza el modelo al usar el conjunto de **test**. Esto nos dice qué tan bien podemos esperar que el modelo prediga cuándo lo usamos en el mundo real. Utiliza el método `evaluate` con los datos de test normalizados y sus labels.
#
# Con el método evaluate devolverá tres valores: loss, mae y mse.

# %% [markdown]
# Ahora prueba el modelo. Coge 10 ejemplos de test y llama a` model.predict`.

# %%
model.evaluate(X_test_scal, y_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7700 - mae: 2.0414 - mse: 6.7700
# [6.770038604736328, 2.0413591861724854, 6.770038604736328]

# %%
df.describe()
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.199187   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   95.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year      Origin         USA      Europe  \
# count    398.000000  398.000000  398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864    0.625628    0.175879
# std        2.757689    3.697627    0.802055    0.484569    0.381197
# min        8.000000   70.000000    1.000000    0.000000    0.000000
# 25%       13.825000   73.000000    1.000000    0.000000    0.000000
# 50%       15.500000   76.000000    1.000000    1.000000    0.000000
# 75%       17.175000   79.000000    2.000000    1.000000    0.000000
# max       24.800000   82.000000    3.000000    1.000000    1.000000
#
#             Japan  Consumo Marca    le_marca
# count  398.000000     398.000000  398.000000
# mean     0.198492      23.514573   16.381910
# std      0.399367       5.158094    9.771179
# min      0.000000       9.000000    1.000000
# 25%      0.000000      19.694118    8.000000
# 50%      0.000000      21.703226   14.000000
# 75%      0.000000      28.372000   26.000000
# max      1.000000      39.016667   37.000000

# %% [markdown]
# ### Haz Predicciones
#
# Dibuja en un scatter plot las predicciones de test vs sus true labels.

# %%
model.predict(X_test_scal[:10])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# array([[14.744052],
#        [15.112767],
#        [21.029707],
#        [23.492292],
#        [18.078062],
#        [12.687477],
#        [19.101452],
#        [25.558758],
#        [25.234589],
#        [27.048855]], dtype=float32)

# %%
y_pred = model.predict(X_test_scal)
y_pred
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# array([[14.744052 ],
#        [15.112767 ],
#        [21.029707 ],
#        [23.492292 ],
#        [18.078062 ],
#        [12.687477 ],
#        [19.101452 ],
#        [25.558758 ],
#        [25.234589 ],
#        [27.048855 ],
#        [28.83148  ],
#        [30.754276 ],
#        [26.420803 ],
#        [25.116734 ],
#        [24.337196 ],
#        [14.172069 ],
#        [14.182018 ],
#        [13.703205 ],
#        [18.748018 ],
#        [29.683378 ],
#        [12.901712 ],
#        [12.687868 ],
#        [16.160778 ],
#        [24.680914 ],
#        [15.790916 ],
#        [26.026245 ],
#        [28.666304 ],
#        [14.8968   ],
#        [16.404404 ],
#        [17.707722 ],
#        [19.717392 ],
#        [22.34846  ],
#        [16.046404 ],
#        [15.908388 ],
#        [16.578081 ],
#        [15.134699 ],
#        [20.468697 ],
#        [17.8956   ],
#        [29.091015 ],
#        [20.884916 ],
#        [14.3769455],
#        [16.081907 ],
#        [29.894981 ],
#        [29.844303 ],
#        [27.00209  ],
#        [25.761253 ],
#        [18.019583 ],
#        [17.966959 ],
#        [19.764065 ],
#        [21.217083 ],
#        [17.6393   ],
#        [19.03788  ],
#        [31.807814 ],
#        [26.815094 ],
#        [29.147953 ],
#        [24.107668 ],
#        [36.43669  ],
#        [34.793056 ],
#        [35.601738 ],
#        [27.134148 ],
#        [28.19398  ],
#        [36.524467 ],
#        [25.718172 ],
#        [22.027569 ],
#        [31.845171 ],
#        [28.891994 ],
#        [36.628452 ],
#        [26.960468 ],
#        [37.236526 ],
#        [37.558495 ],
#        [35.361843 ],
#        [29.339672 ],
#        [29.22979  ],
#        [20.465473 ],
#        [26.714582 ],
#        [36.109985 ],
#        [28.52672  ],
#        [33.534073 ],
#        [34.94752  ],
#        [27.338322 ]], dtype=float32)

# %% [markdown]
# Parece que nuestro modelo predice razonablemente bien. Echemos un vistazo a la distribución de errores.
#
# Representa los residuos en un histograma

# %%
plt.scatter(y_test, y_pred)

# %%
y_pred
# Out:
# array([[14.744052 ],
#        [15.112767 ],
#        [21.029707 ],
#        [23.492292 ],
#        [18.078062 ],
#        [12.687477 ],
#        [19.101452 ],
#        [25.558758 ],
#        [25.234589 ],
#        [27.048855 ],
#        [28.83148  ],
#        [30.754276 ],
#        [26.420803 ],
#        [25.116734 ],
#        [24.337196 ],
#        [14.172069 ],
#        [14.182018 ],
#        [13.703205 ],
#        [18.748018 ],
#        [29.683378 ],
#        [12.901712 ],
#        [12.687868 ],
#        [16.160778 ],
#        [24.680914 ],
#        [15.790916 ],
#        [26.026245 ],
#        [28.666304 ],
#        [14.8968   ],
#        [16.404404 ],
#        [17.707722 ],
#        [19.717392 ],
#        [22.34846  ],
#        [16.046404 ],
#        [15.908388 ],
#        [16.578081 ],
#        [15.134699 ],
#        [20.468697 ],
#        [17.8956   ],
#        [29.091015 ],
#        [20.884916 ],
#        [14.3769455],
#        [16.081907 ],
#        [29.894981 ],
#        [29.844303 ],
#        [27.00209  ],
#        [25.761253 ],
#        [18.019583 ],
#        [17.966959 ],
#        [19.764065 ],
#        [21.217083 ],
#        [17.6393   ],
#        [19.03788  ],
#        [31.807814 ],
#        [26.815094 ],
#        [29.147953 ],
#        [24.107668 ],
#        [36.43669  ],
#        [34.793056 ],
#        [35.601738 ],
#        [27.134148 ],
#        [28.19398  ],
#        [36.524467 ],
#        [25.718172 ],
#        [22.027569 ],
#        [31.845171 ],
#        [28.891994 ],
#        [36.628452 ],
#        [26.960468 ],
#        [37.236526 ],
#        [37.558495 ],
#        [35.361843 ],
#        [29.339672 ],
#        [29.22979  ],
#        [20.465473 ],
#        [26.714582 ],
#        [36.109985 ],
#        [28.52672  ],
#        [33.534073 ],
#        [34.94752  ],
#        [27.338322 ]], dtype=float32)

# %%
y_pred[0]
# Out:
# array([14.744052], dtype=float32)

# %%
error = y_pred.ravel() - y_test
plt.hist(error, bins=15)
plt.title("Distribución errores");

# %%
#error = y_pred[0] - y_test
#plt.hist(error, bins=15)
#plt.title("Distribución errores");

# %% [markdown]
# No es del todo gaussiano, pero podríamos esperar eso porque el número de muestras es muy pequeño.

# %% [markdown]
# Guarda tu modelo en un archivo.

# %%
model.save("final_model.keras")

# %%
imported_model = keras.models.load_model("final_model.keras")
imported_model
# Out:
# <Sequential name=sequential, built=True>

# %% [markdown]
# ## Conclusion
